# %% [markdown]
# # Creating Peers from Universe
#
# Here we'll create a dataframe and csv of our universe and include each companies peer companies and other relevant metadata

# %%
import boto3
import csv
import pandas as pd
import time

universe_path = '/Users/markwindsor/Desktop/atlas_trade/src/data/universe.csv'

df = pd.read_csv(universe_path)


# Configure the AWS credentials and region
aws_access_key_id = ''
aws_secret_access_key = ''
region_name = 'us-east-1'

# Create a DynamoDB client
dynamodb = boto3.client('dynamodb', aws_access_key_id=aws_access_key_id,
                        aws_secret_access_key=aws_secret_access_key, region_name=region_name)

# Define the query parameters
table_name = 'equity-dev'

data = []

for index, row in df.iterrows():
    symbol = row['ticker']
    row_values = {}

    if symbol and not pd.isna(symbol):
        query_params = {
            'TableName': table_name,
            'KeyConditionExpression': 'symbol = :symbol',
            'ExpressionAttributeValues': {
                ':symbol': {'S': symbol}
            },
        }

        # Query the table
        response = dynamodb.query(**query_params)

        # Extract the peers from the response as a list
        items = response.get('Items', [])
        if items:
            company_data = items[0]  # Assuming there's only one matching item
            peers = company_data.get('peers', {}).get('L', [])

            # 'peers' will contain a list of peer companies
            if peers:
                # Extract the values from the DynamoDB List
                peer_list = [item['S'] for item in peers]
                print(f"Peers for {symbol}: {peer_list}")
                row_values['ticker'] = symbol
                row_values['name'] = row['name']
                row_values['famaindustry'] = row['famaindustry']
                row_values['sector'] = row['sector']
                row_values['firstadded'] = row['firstadded']
                row_values['scalemarketcap'] = row['scalemarketcap']
                row_values['peers'] = peer_list
                data.append(row_values)
                # time.sleep(1)
            else:
                print(f"No peers found for symbol {symbol}")
        else:
            print(f"No data found for symbol {symbol}")

result_df = pd.DataFrame(data)

result_df.to_csv('peers.csv', index=False)
# Out:
# No peers found for symbol FMST
# No data found for symbol NNAGU
# No data found for symbol SEZL
# No peers found for symbol SRM
# No data found for symbol SPGC
# Peers for DBD: ['IMMR', 'IVAC', 'HEAR', 'QMCO', 'ALOT', 'TACT', 'OSS', 'MOVE', 'AAPL']
# No data found for symbol LQR
# No data found for symbol NRXS
# No data found for symbol FTEL
# No data found for symbol MIRA
# No data found for symbol SRFM
# No data found for symbol PXDT
# No data found for symbol CTNT
# No data found for symbol HRYU
# No data found for symbol SN
# No data found for symbol HYAC.U
# No data found for symbol KVACU
# No data found for symbol ELWS
# No data found for symbol WRNT
# No data found for symbol JNVR
# No data found for symbol TSBX
# No data found for symbol ODD
# No data found for symbol BATRA
# No data found for symbol APGE
# No data found for symbol NETDU
# No data found for symbol SGMT
# No data found for symbol BOWN
# No data found for symbol SXTP
# No data found for symbol PWM
# No data found for symbol ELVA
# No data found for symbol PHIN
# No peers found for symbol FTRE
# No data found for symbol VTMX
# No data found for symbol SVV
# No data found for symbol KGS
# No data found for symbol FIHL
# No data found for symbol INTS
# No data found for symbol BUJA
# No data found for symbol GENK
# No data found for symbol CISS
# No data found for symbol BOF
# No data found for symbol AZTR
# No data found for symbol CAVA
# No data found for symbol ESHA
# No data found for symbol INDV
# No data found for symbol ATMU
# No data found for symbol KNF
# No data found for symbol IPXX
# No data found for symbol LAES
# No peers found for symbol MGRM
# No data found for symbol SGE
# No data found for symbol CWD
# No data found for symbol BCAL
# No data found for symbol SLRN
# No data found for symbol KVUE
# No data found for symbol ALCY
# No data found for symbol GODN
# No data found for symbol TRNR
# No data found for symbol BHRB
# No data found for symbol JYD
# No data found for symbol USGO
# No data found for symbol UCAR
# No data found for symbol WLGS
# No data found for symbol AACT
# Peers for MSGE: ['ROKU', 'WWE', 'MSGS', 'AMC', 'CNK', 'SEAT', 'MCS', 'RSVR', 'DIS']
# No data found for symbol BANL
# No data found for symbol TCJH
# No data found for symbol TPET
# No data found for symbol GDTC
# No data found for symbol VCIG
# No data found for symbol PKST
# No data found for symbol GDHG
# No data found for symbol ARBB
# No data found for symbol MWG
# No data found for symbol ISPR
# No data found for symbol MGIH
# Peers for CR: ['AQUA', 'TKR', 'WTS', 'GTLS', 'FLS', 'FELE', 'MLI', 'AIMC', 'ITW']
# No data found for symbol HSHP
# No data found for symbol STHO
# No data found for symbol SYT
# No data found for symbol SFWL
# No data found for symbol CHSN
# No data found for symbol HKIT
# No data found for symbol TBMC
# No peers found for symbol HLP
# No data found for symbol YGF
# No data found for symbol TMTC
# No data found for symbol ZJYL
# No data found for symbol OAKU
# No data found for symbol OMH
# No data found for symbol MGRX
# No data found for symbol CLCO
# No peers found for symbol FORL
# No data found for symbol ICG
# No data found for symbol IZM
# No data found for symbol AESI
# No data found for symbol AIXI
# No data found for symbol TORO
# No data found for symbol SBXC
# No data found for symbol BMR
# No data found for symbol STRW
# No data found for symbol NFTG
# No data found for symbol DIST
# No data found for symbol MARX
# No data found for symbol BFRG
# No data found for symbol ENLT
# No data found for symbol MLYS
# No data found for symbol BLAC
# No data found for symbol PTHR
# No data found for symbol HSAI
# No data found for symbol NXT
# No data found for symbol LSDI
# No data found for symbol LICN
# No data found for symbol ASST
# No data found for symbol GPCR
# No data found for symbol CETU
# No data found for symbol BREA
# No data found for symbol TXO
# No data found for symbol GNLX
# No data found for symbol QSG
# No data found for symbol EU
# Peers for CVKD: ['ACUS', 'SYNI', 'JNJ']
# Peers for VTS: ['REPX', 'SBOW', 'SD', 'EGY', 'REI', 'GDP', 'COP']
# No data found for symbol ISRL
# Peers for MGOL: ['SQBGQ']
# Peers for AMLI: ['TECK']
# Peers for GEHC: ['BDX', 'BSX', 'EW', 'DXCM', 'IDXX', 'RMD', 'ZBH', 'PODD', 'BAX', 'ABT']
# No peers found for symbol ATMC
# Peers for COYA: ['ASMB', 'AVRO', 'XGN', 'ALGS', 'NXTC', 'IMUC', 'SLS', 'CADL', 'LPTX']
# No data found for symbol ATMV
# No data found for symbol HSPO
# Peers for LIPO: ['APRE', 'PSTV', 'ARDS', 'BLPH', 'DFFN', 'CRBP', 'CYCC', 'NERV']
# Peers for MBC: ['CSWI', 'GFF', 'DOOR', 'ROCK', 'JBI', 'PGTI', 'JELD', 'APOG', 'AZZ', 'CARR']
# Peers for RAYA: ['CBAT']
# Peers for BAM: ['BN']
# Peers for JEWL: ['ATLX', 'AUMN']
# No peers found for symbol KWE
# Peers for FG: ['LNC', 'BHF', 'AEL', 'GNW', 'CNO', 'TRUP', 'NWLI', 'OSCR', 'IHC', 'MET']
# Peers for DRS: ['BWXT', 'PSN', 'AJRD', 'MAXR', 'SPR', 'MOG.A', 'MRCY', 'AVAV', 'RKLB', 'RTX']
# Peers for CMND: ['INM']
# Peers for ATAT: ['GHG']
# Peers for ACRV: ['STOK', 'ICVX', 'ACET', 'PMVP', 'STRO', 'INO', 'VERA', 'ORGO', 'RCEL']
# No peers found for symbol PLTN
# Peers for SNAL: ['MYPS', 'SKLZ', 'GMGI', 'MSGM', 'ATVI']
# Peers for ASPI: ['NTIC', 'FTK', 'NANX', 'ADES', 'TORM', 'SHW']
# Peers for RXO: ['R', 'XPO', 'LYFT', 'WERN', 'ARCB', 'MRTN', 'HTLD', 'ULH', 'PTSI', 'UBER']
# Peers for MBLY: ['REE']
# Peers for PRME: ['BBIO', 'KYMR', 'VCYT', 'NUVL', 'BCRX', 'SNDX', 'MORF', 'CPRX', 'RNA']
# Peers for SDRL: ['VAL', 'NBR']
# No peers found for symbol HUDA
# No peers found for symbol TENK
# No peers found for symbol EFXT
# Peers for CTM: ['CISO', 'RSSS', 'DPSI', 'VRAR', 'CSPI', 'OMQS', 'IBM']
# No peers found for symbol SVII
# No peers found for symbol VOXR
# Peers for MPTI: ['AIRG', 'CPSH', 'DYSL', 'TMPO', 'LGL', 'AMPG', 'APH']
# Peers for BHM: ['BRG', 'BRT', 'CLPR', 'AVB']
# Peers for BHVN: ['ABUS', 'NRIX', 'VIGL', 'IRON', 'CNCE', 'PEPG', 'ATRA', 'VOR', 'DSGN']
# No peers found for symbol AQU
# No peers found for symbol DMYY
# Peers for XPER: ['ZUO', 'ATEN', 'ADEA', 'SCWX', 'OSPN', 'TUFN', 'ZFOX', 'TLS', 'MSFT']
# No peers found for symbol QOMO
# Peers for LASE: ['TAYD', 'CVR', 'GTEC', 'ITW']
# No data found for symbol NXU
# No peers found for symbol GLST
# Peers for NYAX: ['INVZ', 'ARBE']
# Peers for THRD: ['ANTX', 'KMPH', 'OPTN', 'XERS', 'CTXR', 'IMRA', 'CRMD', 'JNJ']
# Peers for LNKB: ['FFDF', 'PROV', 'SBFG', 'SFBC', 'PNC']
# Peers for NXL: ['HSDT', 'DYNT', 'INVO', 'NAOV', 'MICR', 'RMED', 'LHDX', 'INBS', 'ABT']
# Peers for CRBG: ['APO', 'EQH', 'VOYA', 'JXN', 'ALRS', 'BXLC']
# Peers for WLDS: ['NNDM', 'OTIVF']
# No peers found for symbol EFHT
# Peers for YOSH: ['LUB', 'BDL', 'GRIL', 'BFI', 'GTIM', 'RAVE', 'BTBD', 'MCD']
# Peers for SHPH: ['VINC', 'NHWK', 'AGLE', 'ONVO', 'AGE', 'VCNX', 'ABVC']
# Peers for BIAF: ['RGRX', 'AIMD', 'HILS', 'SLNO', 'CLVSQ', 'TOVX', 'IBIO']
# Peers for ATXG: ['BEST']
# No peers found for symbol TFPM
# Peers for HPCO: ['TPB', 'XXII', 'CHUC', 'PM']
# Peers for JFBR: ['GLBE']
# Peers for JZ: ['STG', 'BEDU', 'AACG', 'TEDU', 'YQ', 'GSUN']
# Peers for ONFO: ['KBNT', 'CRTD', 'AUTO', 'GOOGL']
# Peers for PXMD: ['ZYNE', 'LCI', 'NMTR', 'JNJ']
# Peers for MOB: ['SATX', 'BOSC', 'RITT', 'RDWR']
# No peers found for symbol STBX
# No peers found for symbol GCT
# No peers found for symbol GRFX
# Peers for LUCY: ['POAI', 'RMTI', 'SIEN', 'CEMI', 'SRGA', 'NXGL', 'STSS']
# Peers for LUXH: ['INTG', 'MAYS', 'WAYS', 'SFR', 'CPTP', 'RFL', 'TPHS', 'DBRG']
# Peers for FRZA: ['AOUT', 'NLS', 'VEEE', 'HAS']
# Peers for REBN: ['WMK', 'IMKTA', 'VLGEA', 'NGVC', 'APRN', 'IFMK', 'CRMBQ', 'KR']
# Peers for TGL: ['HHS', 'DRCT', 'LYLT', 'SWAG', 'SGRP', 'BMTM', 'TRKA', 'TTD']
# No data found for symbol ABLV
# Peers for NCRA: ['WLMS', 'OIG', 'QTEK', 'ISUN', 'SGBX', 'PWR']
# No peers found for symbol EMCG
# No peers found for symbol BRSH
# No peers found for symbol PTWO
# No peers found for symbol MOBV
# Peers for MEGL: ['LGHL']
# Peers for EFSH: ['MMM', 'IEP', 'SPLP', 'VINO', 'HON']
# Peers for FIP: ['UNP', 'CSX', 'NSC']
# Peers for MGAM: ['GAIA', 'FGH', 'DLPN', 'MITQ', 'DIS']
# Peers for MAIA: ['BCEL', 'TYME', 'CYT', 'SYBX', 'SPRB', 'ONCT', 'GANX', 'AQB']
# Peers for ECBK: ['BSBK', 'SNFCA', 'RNDB', 'GFED', 'CFBK', 'OFED', 'PBIP', 'RBKB', 'PROV', 'RKT']
# Peers for HLN: ['ABTI']
# No peers found for symbol VRAX
# Peers for HKD: ['KARO', 'TRIRF']
# Peers for ILAG: ['TGSI', 'AEHL']
# Peers for PMN: ['PRTG', 'XENE']
# Peers for USEA: ['ESEA', 'SHIP', 'PXS', 'EDRY', 'GLBS', 'OP', 'PSHG', 'SBLK']
# Peers for EHAB: ['CCRN', 'DCGO', 'FLGT', 'OPK', 'ACCD', 'CSTL', 'NVTA', 'CMAX', 'CVS']
# No peers found for symbol IONR
# No data found for symbol OCTO
# Peers for IE: ['LAC', 'TECK']
# No peers found for symbol SKGR
# No peers found for symbol INTR
# Peers for GSUN: ['BEDU', 'JZ', 'AACG', 'TEDU', 'YQ', 'LXEH', 'CLEU', 'ZCMD']
# Peers for IPX: ['ATLX', 'AUMN', 'JEWL']
# No peers found for symbol FLFV
# Peers for NEOV: ['GWH', 'BEEM', 'AMSC', 'DFLI', 'KULR', 'FLUX', 'OESX', 'RMO', 'EMR']
# Peers for LYT: ['ANGH', 'EMWPF']
# Peers for CNXA: ['HAS']
# Peers for HSCS: ['NURO', 'FEMY', 'BJDX', 'MYO', 'CFMS', 'AEMD', 'NDRA', 'BIOL', 'UTRS', 'ABT']
# No peers found for symbol ACAC
# Peers for PEV: ['GOEV', 'RIDE', 'CENN', 'EVTV', 'AYRO', 'ELMSQ', 'TSLA']
# Peers for SVRE: ['SNT', 'RVSN', 'MTEK', 'SPCB']
# Peers for TOP: ['AMTD']
# No peers found for symbol BCAN
# Peers for ODV: ['GROY']
# No peers found for symbol BNRG
# Peers for AZPN: ['PAYC', 'PLTR', 'FICO', 'SPLK', 'PTC', 'TYL', 'DT', 'U', 'DOCU', 'CTXS']
# Peers for IAUX: ['NEM', 'RGLD', 'SSRM', 'NG', 'CDE']
# Peers for BGXX: ['CTXR', 'IMRA', 'CRMD', 'TRVI', 'IKNA', 'SBBP', 'SCTL', 'RVLP', 'JNJ']
# Peers for OKYO: ['NCNA', 'ORTX', 'TLSA', 'ACHL', 'ROIV']
# Peers for VEDU: ['NAII', 'BRFH', 'SANW', 'DTEA', 'LFVN', 'TKLF']
# Peers for ASNS: ['ATGN', 'COMS', 'MINM', 'TKOI', 'BDRL', 'CSCO']
# No data found for symbol NCNC
# Peers for ACDC: ['BKR', 'NOV', 'CHX', 'WFRD', 'WHD', 'LBRT', 'NEX', 'TDW', 'USAC', 'SLB']
# No peers found for symbol MCAC
# Peers for HNVR: ['RVSB', 'FCCO', 'FRAF', 'FNWB', 'EBMT', 'PNC']
# No peers found for symbol GBBK
# No peers found for symbol IVCA
# Peers for BLCO: ['PEN', 'PRGO', 'TDOC', 'EHC', 'DNA', 'INSP', 'GMED', 'DOCS', 'ATR', 'NVST']
# No peers found for symbol RENE
# Peers for PEPG: ['NRIX', 'VIGL', 'IRON', 'CNCE', 'BHVN', 'ATRA', 'VOR', 'DSGN', 'MGNX']
# Peers for EDBL: ['RKDA', 'KAL', 'ADM']
# Peers for AUST: ['PZG', 'FSI', 'EXN', 'ITP', 'AAU', 'XPL', 'UAMY', 'WWR', 'AUMN', 'ITRG']
# No peers found for symbol ASCB
# Peers for BLTE: ['ATRS', 'COLL', 'INVA', 'ACRS', 'FULC', 'CBAY', 'AERI', 'JNJ']
# Peers for HLVX: ['DYN', 'AGEN', 'ALT', 'ARDX', 'FATE', 'ZYME', 'CHRS', 'ERAS', 'LYEL']
# No peers found for symbol CHEA
# No peers found for symbol CLRC
# Peers for OST: ['PBTS', 'MINM', 'ELTK', 'INPX', 'DAIO', 'DATS', 'GVP', 'BSQR', 'VJET']
# Peers for ELBM: ['TECK']
# Peers for JMSB: ['CSTR', 'FISI', 'GNTY', 'RBB', 'MCBC', 'ESQ', 'NBN', 'PNC']
# Peers for TNON: ['PETV', 'TLIS', 'NMTC', 'BEAT', 'NMRD', 'MODD', 'ABT']
# No data found for symbol AIMAU
# Peers for JCSE: ['DLHC', 'ACTG', 'BWMN', 'PKOH', 'YELL', 'HQI', 'CTRM']
# Peers for ACON: ['ISPC', 'HCTI', 'WORX', 'MEDS', 'CERN']
# No peers found for symbol YOTA
# Peers for STSS: ['SIEN', 'CEMI', 'LUCY', 'SRGA', 'NXGL']
# No peers found for symbol AFAR
# Peers for EE: ['ETRN', 'PAGP', 'CEQP', 'INSW', 'HEP', 'RTLR', 'DKL', 'NS', 'GEL', 'EPD']
# Peers for GNS: ['COE']
# Peers for CRGE: ['LILA', 'SATS', 'ASTS', 'ATEX', 'BAND', 'IRDM']
# No peers found for symbol DECA
# Peers for DC: ['GORO', 'HYMC', 'NEM']
# Peers for ESAB: ['MLI', 'AIMC', 'GTES', 'FLOW', 'JBT', 'WBT', 'AIN', 'SPXC', 'HI', 'ITW']
# Peers for XPON: ['WWR', 'ORBT', 'SVT', 'NVVE', 'PEGY', 'EMR']
# Peers for EMBC: ['NEOG', 'MMSI', 'HAE', 'STAA', 'SILK', 'VIVO', 'FIGS', 'AVNS', 'ATRI']
# No peers found for symbol MSSA
# Peers for RVSN: ['SNT', 'MTEK', 'SPCB']
# No peers found for symbol RWOD
# Peers for DO: ['NE', 'HP', 'NE', 'PTEN', 'PKDC', 'USWS', 'ICD']
# Peers for ANTX: ['BTMD', 'SCPH', 'ASRT', 'OMER', 'KMPH', 'OPTN', 'JNJ']
# Peers for LCFY: ['GIGM', 'CRTD', 'COMS', 'GAME', 'ISIG', 'QTT', 'CNET']
# No peers found for symbol RFAC
# Peers for ZTEK: ['BLCO']
# Peers for GDST: ['EMCF', 'VBOC', 'SFBC', 'UBOH', 'AFBI', 'WTMA', 'CLAY', 'CIZN', 'UNAM']
# Peers for BBUC: ['HON', 'GE', 'MMM', 'IEP', 'SPLP', 'EFSH', 'VINO']
# Peers for FEAM: ['CTGO', 'REEMF']
# Peers for AKAN: ['ISPC', 'ZIVO', 'ADXN', 'MRAI', 'EDSA', 'MRKR', 'RVPH', 'NEPT', 'ACXP']
# Peers for POET: ['CSIQ', 'CSIQ', 'MMAT']
# No peers found for symbol NUBI
# No peers found for symbol PLAO
# Peers for LBBB: ['EMCF', 'VBOC', 'SFBC', 'UBOH', 'AFBI', 'WTMA', 'CLAY', 'CIZN', 'UNAM']
# No peers found for symbol AMPX
# Peers for ZIMV: ['AXGN', 'SRDX', 'HLTH', 'TCMD', 'ARAY', 'ZOM', 'IIN', 'ABT']
# No peers found for symbol SHUA
# Peers for IXHL: ['RXST', 'RPTX', 'SNCE', 'OGI', 'NYXH', 'IVA', 'VRDN', 'SGHT', 'PTGX', 'AKYA']
# No peers found for symbol VMCA
# No data found for symbol BTM
# No peers found for symbol CLIN
# Peers for PWUP: ['CIZN', 'CLAY', 'WTMA', 'AFBI', 'UBOH', 'SFBC', 'VBOC', 'EMCF', 'UNAM']
# Peers for BWV: ['FNCH', 'TPST', 'MRKR', 'SONN', 'YTEN', 'ACGN', 'RGRX']
# Peers for FTII: ['CIZN', 'CLAY', 'WTMA', 'AFBI', 'UBOH', 'SFBC', 'VBOC', 'EMCF', 'UNAM']
# Peers for MHUA: ['SRTS', 'IMPL', 'ALLK', 'HGEN', 'VOR', 'QIPT', 'NPCE', 'CLNN', 'CGEN', 'SVRA']
# Peers for SMFL: ['GHSI', 'CYAN', 'SPCO', 'CAWW', 'RELV', 'EL']
# Peers for ASCA: ['PFX', 'ARIZ', 'MCAG', 'MGYR', 'CULL', 'LBBB']
# No data found for symbol ESGL
# Peers for SBFM: ['NYMX', 'EDSA', 'LMNL', 'XENE']
# Peers for MDV: ['CTO', 'OZ', 'PINE', 'NYC', 'MDRR', 'SQFT', 'WPC']
# Peers for RACY: ['ARYE', 'RACB', 'BLSA', 'OCAX', 'GREE', 'ARYD', 'MHLD', 'CCAI']
# Peers for DRCT: ['SCOR', 'MCHX', 'DMS', 'HHS', 'LYLT', 'SWAG', 'SGRP', 'TGL', 'TTD']
# Peers for TCBP: ['ROIV']
# No peers found for symbol JGGC
# No peers found for symbol HNRA
# Peers for HTCR: ['NXPL', 'AMPG', 'AHI', 'DUOT', 'BLBX', 'PALT', 'SCKT', 'TAIT']
# No peers found for symbol EVGR
# No peers found for symbol BYNO
# No peers found for symbol LIVB
# Peers for ATAK: ['SHCA', 'BOCH', 'GLRE', 'ENER', 'CDAQ', 'FRW', 'IQMD', 'PBFS']
# Peers for AREB: ['CIX', 'ARC', 'ACU', 'VIRC', 'MSA']
# Peers for NVCT: ['OLMA', 'GOSS', 'INMB', 'LJPC', 'MACK', 'AKBA', 'SPPI', 'GRPH', 'SRNE']
# Peers for ACLX: ['RYTM', 'RCUS', 'VRDN', 'DAWN', 'DVAX', 'IMGO', 'GERN', 'VERV', 'REPL']
# No peers found for symbol MURF
# Peers for PDLB: ['TSBK', 'FSBW', 'OCN', 'NECB', 'HMPT', 'WNEB', 'TBNK', 'ESSA', 'RKT']
# Peers for NVX: ['MVST', 'FCEL', 'PRIM', 'ROCK', 'HURN', 'HEES', 'SKYW', 'SNCY']
# Peers for CEG: ['EXC', 'XEL', 'PCG', 'ES', 'EIX', 'FE', 'ETR', 'PPL', 'AGR', 'NEE']
# Peers for MTEK: ['SNT', 'RVSN', 'SPCB']
# No peers found for symbol ACAX
# Peers for IDAI: ['DUOT', 'IVDA', 'SSNT', 'FALC', 'AUID', 'MSFT']
# Peers for BWAQ: ['MLVF', 'CLDB', 'CWBC', 'PBHC', 'BTBT', 'FCRD', 'MSAC']
# Peers for CRDO: ['OIIM']
# Peers for KSCP: ['BCO', 'CXW', 'GEO', 'ISON']
# Peers for KYCH: ['GMFI', 'ROCG', 'GLLI', 'RVSB', 'PEBK', 'BMAQ', 'MBCN', 'WAVS', 'SMAP', 'HNVR']
# No peers found for symbol LATG
# Peers for FGI: ['MTMT', 'IGC', 'GWW']
# Peers for KNSW: ['BRD', 'RCFA', 'FLAG', 'IRRX']
# Peers for HCMA: ['SDAC', 'SHBI', 'HUT', 'HCNE', 'GLAD', 'SIER', 'DCRD']
# Peers for VZLA: ['TECK']
# Peers for DUET: ['AIB', 'GENQ', 'CBFV', 'FCAP', 'BYFC', 'MSAC', 'PCX', 'FCRD']
# No peers found for symbol GAQ
# No peers found for symbol BYN
# Peers for AIB: ['GENQ', 'DUET', 'CBFV', 'FCAP', 'BYFC', 'MSAC', 'FCRD', 'PCX']
# Peers for NSTS: ['CBMB', 'CFSB', 'IROQ', 'HFBL', 'KFFB', 'FSEA', 'RKT']
# No peers found for symbol TETE
# Peers for TKLF: ['DTEA', 'LFVN', 'MTEX', 'SANW', 'LXEH', 'TUEM', 'AGRI', 'WTER']
# No peers found for symbol ACAB
# Peers for CISO: ['PFSW', 'MLGO', 'CSPI', 'RSSS', 'VRAR', 'DPSI', 'CTM', 'OMQS', 'IBM']
# Peers for PPYA: ['TIPT', 'KRNL', 'AMNB', 'AHRN', 'PFIS', 'FSRX', 'HMCO', 'DHCA', 'IGIC', 'AGGR']
# Peers for TPG: ['NTRS', 'OWL', 'BEN', 'ARES', 'CG', 'ARCC', 'SEIC', 'IVZ', 'AMG', 'BX']
# Peers for CSLM: ['GACQ', 'NRIM', 'TRON', 'BOCN', 'FSBW', 'PBAX', 'PDLB', 'NVAC', 'PANA']
# Peers for CFSB: ['KFFB', 'BOTJ', 'IROQ', 'PNC']
# Peers for WNNR: ['WRAC', 'IRRX', 'DSAQ', 'RCFA', 'KNSW']
# Peers for GHIX: ['CAC', 'NFBK', 'SVFA', 'CFIV', 'VALU', 'VINP']
# Peers for WAVS: ['CIZN', 'CLAY', 'WTMA', 'AFBI', 'UBOH', 'SFBC', 'VBOC', 'EMCF', 'UNAM']
# Peers for HILS: ['ACGN', 'RGRX', 'AIMD', 'BIAF', 'SLNO', 'CLVSQ', 'TOVX']
# Peers for ITAQ: ['HWBK', 'FINW', 'FNWB', 'CALB', 'VABK', 'WMPN']
# Peers for VCXB: ['WDH', 'TWND', 'SUAC']
# Peers for BRAC: ['DUET', 'AIB', 'GENQ', 'CBFV', 'PCX', 'FCAP', 'BYFC', 'MSAC', 'GDNR']
# Peers for CXAC: ['GOGN', 'AMPI']
# Peers for HOUR: ['AKA', 'TDUP', 'RMBL', 'REAL', 'LVLU', 'GROV', 'POL', 'BOXD', 'AMZN']
# Peers for VIGL: ['KZR', 'LXRX', 'ALDX', 'ABUS', 'NRIX', 'IRON', 'CNCE', 'BHVN', 'PEPG']
# Peers for AMLX: ['HRMY', 'AXSM', 'VTYX', 'CORT', 'SUPN', 'PCRX', 'TLRY', 'ARVN', 'JNJ']
# Peers for SCRM: ['OBNK', 'BMTC', 'RBCAA', 'CONX', 'AMRK', 'PFC', 'HFWA', 'JRVR']
# Peers for AZ: ['PPIH', 'ALPP', 'NNBR', 'IVAC', 'HSON', 'TUSK', 'EML']
# Peers for CITE: ['DTRT', 'FRON', 'SVFB', 'USCT', 'CMCA']
# Peers for GMFI: ['KYCH', 'ROCG', 'RVSB', 'GLLI', 'PEBK', 'BMAQ', 'MBCN', 'WAVS', 'HNVR', 'ALSA']
# Peers for DOUG: ['MMI', 'OPEN', 'RDFN', 'HOUS', 'RMAX', 'DOMA', 'OPAD', 'FTHM', 'CBRE']
# Peers for WTMA: ['CLAY', 'AFBI', 'CIZN', 'SFBC', 'KACL', 'UBOH']
# Peers for GDNR: ['RBKB', 'HMNF', 'PCX', 'FVAM', 'PROV', 'VERY', 'AUBN']
# No peers found for symbol AOGO
# Peers for ALLR: ['ADTX', 'SLRX', 'QLGN', 'BBLG', 'LADX', 'HSTO']
# Peers for NXGL: ['RMTI', 'SIEN', 'CEMI', 'LUCY', 'SRGA', 'STSS']
# No peers found for symbol SAGA
# Peers for ZVSA: ['AGLE', 'SRZN', 'ABVC', 'ONVO', 'IKT', 'OTLC', 'CYCN', 'DOMH', 'SLNO']
# Peers for NVAC: ['FSBW', 'BOCN', 'FICV', 'NRIM', 'GACQ', 'CSLM', 'HPLT', 'ORIA']
# Peers for APCA: ['JATT', 'SUPV', 'CIA']
# Peers for RCAC: ['SSBK', 'HSAQ', 'OXSQ', 'AACI', 'CVCY', 'TCFC', 'JAQC']
# Peers for SANG: ['SWIR']
# Peers for SHAP: ['QFTA', 'OPA', 'PHYT']
# Peers for EMLD: ['FTCV', 'DISA', 'JUGG', 'BLEU', 'IIII', 'FTAA', 'FTVI', 'NVSA', 'BLFY']
# Peers for ADRT: ['COHN', 'AAMC', 'IMH', 'DXF', 'AINC', 'MGLD', 'IOR']
# Peers for IMMX: ['EQ', 'SIOX', 'PTN', 'ABIO', 'APGN', 'SGTX', 'MEIP']
# No peers found for symbol CFFS
# Peers for BNOX: ['DBTX', 'RAIN', 'SCYX', 'CDAK', 'ADMP', 'BOLT', 'QLI', 'NVOS', 'IFRX', 'DMAC']
# Peers for BFAC: ['CNDB', 'OPY', 'GFX', 'PSPC', 'ACII', 'RONI', 'MTVC']
# Peers for PRLH: ['SWKH', 'FHLT', 'DALS', 'ORIA', 'VBNK', 'GTAC', 'HPLT']
# Peers for IVCB: ['GNTY', 'ERES', 'VTIQ', 'CPAA', 'SMBC', 'FLIC', 'GIIX', 'NDAC']
# Peers for EVE: ['KCGI', 'NETC', 'ATEK', 'PACI']
# Peers for GNTA: ['PIRS', 'GRPH', 'IPA', 'APYX', 'YI', 'ORIC', 'ADAG', 'GRTS', 'CRMD']
# Peers for OZ: ['STAR', 'GOOD', 'OLP', 'CTO', 'PINE', 'MDV', 'WPC']
# No peers found for symbol IVCP
# Peers for IOT: ['PLAN', 'PCOR', 'BILL', 'MANH', 'ZEN', 'DBX', 'CFLT', 'NTNX', 'CDK', 'CTXS']
# Peers for VINE: ['NAPA', 'VWE', 'SBEV', 'WVVI', 'EAST', 'THST', 'STZ']
# Peers for SIDU: ['AIRI', 'TIKK', 'GIGA', 'RTX']
# Peers for KACL: ['CIZN', 'CLAY', 'WTMA', 'AUBN', 'AFBI', 'VERY', 'SFBC']
# Peers for BRKH: ['EBTC', 'DCRD', 'KVSA', 'HUT', 'SHBI', 'IPAX', 'LX']
# Peers for ALSA: ['HNVR', 'ROCL', 'OXAC', 'WAVS', 'MBCN', 'BMAQ', 'PEBK', 'RVSB', 'GMFI']
# Peers for PORT: ['RCFA', 'KNSW', 'BRD', 'FLAG', 'IRRX']
# Peers for XPDB: ['ARRW', 'SPKB', 'IPVI', 'NODK', 'OPRT', 'LCAA', 'TZPS', 'APTM']
# Peers for TCOA: ['GHL', 'CLBR']
# Peers for GFGD: ['PFTA', 'WHF', 'VPCB', 'GGAA', 'CBNK', 'HIVE', 'ROOT', 'FSSI', 'TCBX']
# Peers for FRBN: ['BSBK', 'CCTS', 'EBMT', 'LION', 'PWOD', 'OHAA', 'EBAC']
# Peers for ATEK: ['NETC', 'EVE', 'KCGI']
# Peers for HAIA: ['CNGL', 'XPAX', 'GLHA', 'TGAA', 'VCXA', 'ARBK', 'SKYA', 'CREC', 'ROC']
# Peers for FXCO: ['CFBK', 'EUCR', 'AEHA', 'OFED', 'FRAF', 'ENCP', 'VSAC']
# No peers found for symbol WEL
# Peers for NRSN: ['EVGN', 'ENTX', 'CMMB']
# Peers for IGTA: ['LARK', 'FUNC', 'UBFO', 'BFIN', 'OPOF', 'FXNC', 'FRLA', 'SBFG']
# Peers for TGAA: ['ARBK', 'CREC', 'ROC', 'XPAX', 'HAIA', 'CHPM', 'CNGL', 'GLHA', 'ORRF']
# Peers for NU: ['BRO', 'L', 'KB', 'SYF', 'FDS', 'SHG', 'RKT', 'CS', 'MKL', 'WRB']
# Peers for HCP: ['COUP', 'INFA', 'GWRE', 'SMAR', 'CCCS', 'VG', 'SPSC', 'APP', 'ALTR', 'CTXS']
# Peers for REFI: ['IVR', 'ORC', 'AFCG', 'GPMT', 'NREF', 'AJX', 'AOMR', 'SACH', 'NLY']
# Peers for CRGY: ['WLL', 'NOG', 'ESTE', 'CPE', 'MNRL', 'TALO', 'ROCC', 'GPOR', 'GRNT', 'COP']
# Peers for CING: ['TTNP', 'PCSA', 'AKTX', 'PULM', 'AGRX', 'JNJ']
# Peers for APXI: ['OXUS', 'TSBK', 'AFAC', 'DUNE', 'FNVT', 'PGRW', 'ASAX', 'THAC', 'PTMN']
# Peers for GLLI: ['ROCG', 'KYCH', 'GMFI', 'SMAP', 'LIBY', 'RVSB', 'DHAC', 'BREZ', 'PEBK', 'FTII']
# No data found for symbol CJET
# Peers for IMPP: ['GPP', 'BKEP', 'SMLP', 'USDP', 'MMLP', 'SLNG', 'SNMP', 'EPD']
# Peers for BOCN: ['FSBW', 'NRIM', 'GACQ', 'NVAC', 'CSLM', 'TRON', 'PBAX', 'FICV', 'PDLB']
# Peers for BIOS: ['CFFE', 'MYFW', 'GWII', 'MCAA', 'BKCC', 'AKIC', 'TOAC', 'PKBK', 'IMAQ']
# Peers for UTAA: ['CBRG', 'HBCP', 'IREN', 'SWAG', 'FIAC', 'MPRA', 'DAOO', 'PCB', 'HRZN']
# No data found for symbol DTI
# Peers for PACI: ['ADEX', 'NFNT', 'EPWR', 'MDH', 'PICC', 'KCGI']
# Peers for ROCL: ['OXAC', 'ALSA', 'HNVR', 'WAVS', 'MBCN', 'BMAQ', 'PEBK', 'RVSB', 'FEXD']
# Peers for CMCA: ['TLGY', 'USCT', 'DPCS', 'FRON', 'CBAN', 'AEAE']
# Peers for TLGY: ['CMCA', 'USCT', 'DPCS', 'FRON', 'CBAN', 'AEAE']
# Peers for BAFN: ['VBFC', 'PNC']
# Peers for OP: ['EDRY', 'USEA', 'GLBS', 'PSHG', 'PRGNF', 'SBLK']
# Peers for CNGL: ['HAIA', 'GLHA', 'XPAX', 'VCXA', 'TGAA', 'SKYA', 'ARBK', 'CREC', 'ROC']
# Peers for MNTN: ['PMVC', 'APN']
# Peers for MKUL: ['AZZ', 'AMWD', 'NX', 'IIIN', 'VIEW', 'TGEN', 'JCTCF', 'AUVI', 'CARR']
# Peers for BRD: ['FLAG', 'KNSW', 'RCFA', 'IRRX']
# Peers for VHNA: ['SMIH', 'APAC', 'GEEX', 'GTAC', 'ARTE', 'VBNK', 'DALS', 'FHLT']
# Peers for CDIO: ['SNGX', 'NRBO', 'RUBY', 'IMNN', 'CYTH', 'BRTX', 'APVO', 'NAVB']
# No data found for symbol SLND
# No peers found for symbol EUDA
# Peers for CBL: ['ALX', 'NTST', 'BFS', 'RTL', 'RPT', 'UBA', 'WSR', 'CDR', 'HMG', 'O']
# Peers for ALOR: ['MEAC', 'SWSS', 'PANA', 'BSVN', 'PDLB']
# Peers for NFNT: ['ADEX', 'EPWR', 'MDH', 'PACI', 'PICC', 'CNDA']
# Peers for AHI: ['DUOT', 'BLBX', 'HTCR', 'PALT', 'NXPL', 'SCKT', 'AMPG', 'TAOP', 'TAIT']
# Peers for FINW: ['LARK', 'CBFV', 'LNKB', 'SBFG', 'PNC']
# Peers for IFIN: ['WAVC', 'TRCA']
# Peers for LITM: ['TECK']
# Peers for TSAT: ['PAYA', 'WKME', 'IIIV', 'CEVA', 'IMXI', 'ARQQ', 'BTRS', 'KARO', 'ACMR']
# Peers for SG: ['PLAY', 'EAT', 'JACK', 'PTLO', 'DIN', 'FWRG', 'BJRI', 'DENN', 'CHUY', 'MCD']
# Peers for ARIZ: ['MCAG', 'PFX', 'ASCA', 'LBBB', 'UBCP', 'MGYR']
# Peers for BLEU: ['FTCV', 'FTVI', 'NVSA', 'EMLD', 'BLFY', 'DISA', 'JUGG', 'IIII', 'SWET']
# Peers for SGII: ['RMBI', 'OPBK', 'ASPS', 'JWAC', 'CFFI', 'LCNB', 'APMI', 'RAM']
# Peers for LFAC: ['IOAC', 'BCBP', 'PEGR', 'BSRR', 'PUCK', 'FNLC', 'FRST']
# Peers for SUAC: ['NFYS', 'SLQT', 'TRTL', 'ACRO', 'TWND']
# Peers for IREN: ['UTAA', 'CBRG', 'HBCP', 'SWAG', 'FIAC', 'MPRA', 'DAOO', 'PCB', 'HRZN']
# Peers for NETC: ['ATEK', 'EVE', 'KCGI']
# Peers for BRZE: ['NCR', 'ENV', 'SPT', 'RNG', 'ASAN', 'NCNO', 'BLKB', 'MSTR', 'ACIW', 'CTXS']
# Peers for ENCP: ['VSAC', 'OTEC', 'FRAF', 'UNB', 'EUCR', 'FXCO', 'CFBK', 'AEHA']
# Peers for ONL: ['PGRE', 'PDM', 'BDN', 'OPI', 'PSTL', 'FSP', 'CMCT', 'ARE']
# Peers for DGHI: ['QBTS']
# Peers for DERM: ['AQST', 'ADMP', 'LPCN', 'ELTP', 'NOVN', 'STSA', 'CPIX', 'JNJ']
# Peers for MYNA: ['LILM']
# Peers for MCAG: ['ARIZ', 'LBBB', 'PFX', 'ASCA', 'UBCP', 'BKSC']
# Peers for IRRX: ['WNNR', 'RCFA', 'KNSW', 'WRAC', 'BRD', 'FLAG']
# Peers for BTBD: ['GRIL', 'BFI', 'GTIM', 'YOSH', 'RAVE', 'MCD']
# Peers for LVLU: ['DIBS', 'AKA', 'TDUP', 'RMBL', 'REAL', 'HOUR', 'GROV', 'POL', 'AMZN']
# Peers for PIK: ['IPW', 'IMBI', 'ID', 'HEWA', 'DBGI', 'ASAP', 'AMZN']
# Peers for LGVC: ['APLD', 'ESAC', 'SFST', 'SMMF', 'FWAC', 'KINZ', 'PEPL', 'TMKR', 'APTM']
# Peers for VAXX: ['OYST', 'GLUE', 'OTLK', 'SVRA', 'RLYB', 'OMGA', 'VYGR', 'HRTX']
# Peers for TIVC: ['THMO', 'RSLS', 'UAHC', 'SINT', 'ABT']
# Peers for BEAT: ['LNSR', 'PETV', 'TLIS', 'NMTC', 'TNON', 'NMRD', 'MODD', 'ABT']
# Peers for WEAV: ['DMRC', 'CIFR', 'BLND', 'BNFT', 'NN', 'PRCH', 'CCRD', 'CTXS']
# Peers for BLZE: ['RXT', 'CYXT', 'EGIO', 'BCOV', 'CORZQ', 'CLWA', 'CXDO', 'SNOW']
# Peers for RCFA: ['PORT', 'KNSW', 'BRD', 'FLAG', 'IRRX']
# Peers for CINT: ['SWI', 'AI', 'WBX', 'SQSP', 'PSFE', 'RAMP', 'NABL', 'KN', 'PD']
# Peers for RIVN: ['TSLA', 'GM', 'F', 'LCID', 'THO', 'NWTN', 'WGO', 'FSR', 'MULN']
# Peers for PRM: ['HCC', 'TSE', 'LXU', 'EGO', 'CMP', 'HBM', 'ECVT']
# Peers for BCSA: ['CCNE', 'EZPW', 'HTBI', 'WTBA', 'BYTS', 'DTOC']
# Peers for CBRG: ['HBCP', 'UTAA', 'IREN', 'SWAG', 'FIAC', 'MPRA', 'DAOO', 'PCB', 'HRZN']
# Peers for BJDX: ['NURO', 'FEMY', 'MYO', 'CFMS', 'HSCS', 'AEMD', 'ABT']
# Peers for EXFY: ['MTTR', 'CCSI', 'YEXT', 'MARA', 'BASE', 'ECOM', 'EGHT', 'CTXS']
# Peers for HTZ: ['UHAL', 'KNX', 'CAR', 'SAIA', 'LSTR', 'SNDR', 'R', 'XPO', 'LYFT', 'UBER']
# Peers for DPCS: ['CMCA', 'CBAN', 'USCT', 'AEAE', 'MPRA']
# Peers for SWAG: ['DMS', 'HHS', 'DRCT', 'LYLT', 'SGRP', 'TGL', 'BMTM', 'TTD']
# No peers found for symbol OLIT
# Peers for SOPA: ['ZDGE', 'IZEA', 'PALT', 'LFLY', 'SLGG', 'GOOGL']
# Peers for DRUG: ['SBFM', 'LMNL', 'XENE']
# Peers for TCBX: ['PCB', 'BCML', 'SSBK', 'PLBC', 'USCB', 'INBK', 'PNC']
# Peers for RRAC: ['JUN', 'HTPA', 'ACDI', 'CHAA']
# Peers for MYNZ: ['AFMD', 'IFRX', 'BNTX']
# Peers for MCAA: ['BKCC', 'GWII', 'AKIC', 'TOAC', 'PKBK', 'BIOS', 'CFFE', 'MYFW']
# Peers for NPAB: ['RCLF', 'CIVB', 'MCBC', 'TCBX']
# Peers for SKE: ['MMX']
# Peers for IOBT: ['EVAX', 'FWPAY']
# Peers for RGF: ['LFCR', 'FREE', 'BRID', 'TTCF', 'FARM', 'LWAY', 'MMMB', 'MGLD', 'MDLZ']
# Peers for TSVT: ['AVEO', 'MRSN', 'MDXG', 'CGEM', 'PSTX', 'ALLK', 'AKUS', 'CMPX', 'RDUS']
# Peers for FNVT: ['DUNE', 'AFAC', 'ASAX', 'APXI', 'THAC', 'PTMN', 'TSBK', 'PGRW']
# Peers for DHAC: ['LIBY', 'BREZ', 'SMAP', 'FTII', 'PONO', 'GLLI', 'ROCG', 'KYCH', 'GMFI']
# Peers for MPRA: ['XFIN', 'AEAE', 'FIAC', 'CBAN', 'SWAG', 'IREN', 'UTAA', 'CBRG', 'HBCP', 'DPCS']
# Peers for LGST: ['HBT', 'BFST', 'FCBC', 'FDUS', 'TETC', 'CCB', 'GAIN']
# Peers for KD: ['CTSH', 'IT', 'EPAM', 'DOX', 'DXC', 'TWKS', 'PRFT', 'GDYN', 'HCKT', 'IBM']
# Peers for LIBY: ['DHAC', 'SMAP', 'BREZ', 'FTII', 'PONO', 'GLLI', 'ROCG', 'KYCH', 'GMFI']
# Peers for JUN: ['HTPA', 'RRAC', 'CHAA', 'ACDI']
# Peers for CNDB: ['PSPC', 'BFAC', 'OPY', 'GFX', 'ACII']
# No data found for symbol SMX
# Peers for SZZL: ['ARCK', 'ISAA', 'PTMN', 'CENQ', 'THAC', 'ASAX', 'SSSS', 'CVLY']
# Peers for MDXH: ['AMTI', 'GTH', 'MNOV', 'OLMA', 'STTK', 'OCX', 'PSTX', 'HEXO', 'NMTR', 'JSPR']
# Peers for ARHS: ['WSM', 'RH', 'SNBR', 'HVT', 'AAN', 'BBBY', 'KIRK']
# Peers for CDRE: ['SPCE', 'VVX', 'ASLE', 'PAE', 'TGI', 'KAMN', 'DCO', 'ACHR', 'NPK', 'RTX']
# Peers for NRDS: ['NAVI', 'BFH', 'PRAA', 'ENVA', 'UPST', 'ECPG', 'PRG', 'LC', 'GDOT', 'AXP']
# Peers for ONYX: ['LVRA', 'NCAC', 'SBT', 'FTAA', 'IIII', 'JUGG', 'DISA']
# Peers for TGVC: ['LVAC', 'GIAC', 'LMST', 'FATP', 'FCCO', 'WINV', 'MTRY', 'FEXD', 'INTE']
# Peers for INTE: ['WINV', 'FCCO', 'OVLY', 'TGVC', 'LVAC', 'GIAC', 'LMST']
# Peers for FRLA: ['SBFG', 'OPOF', 'BFIN', 'UBFO', 'UNB', 'FUNC', 'IGTA']
# Peers for CMPX: ['ERAS', 'MRSN', 'ANIK', 'NRIX', 'SRRK', 'CGEM', 'KPTI', 'CNCE', 'BHVN']
# Peers for BIRD: ['DECK', 'CROX', 'SKX', 'SHOO', 'WWW', 'RCKY', 'NKE']
# Peers for CMTG: ['STWD', 'RITM', 'BXMT', 'HASI', 'ABR', 'TWO', 'ARI', 'CIM', 'LADR', 'NLY']
# Peers for VSAC: ['OTEC', 'ENCP', 'UNB', 'FRAF', 'SBFG', 'EUCR', 'FXCO']
# Peers for LIAN: ['ATXS', 'NKTX', 'LCTX', 'ABSI', 'OCGN', 'GRTS', 'JSPR', 'STTK', 'GLSI']
# Peers for TRDA: ['VNDA', 'CRBU', 'KOD', 'MGTX', 'ALPN', 'BMEA', 'KPTI', 'STOK', 'ICVX']
# Peers for SONX: ['STIM', 'CTSO', 'EAR', 'NPCE', 'DRIO', 'SRTS', 'FONR', 'ELMD', 'ABT']
# Peers for HRT: ['KFY', 'FA', 'UPWK', 'KFRC', 'STER', 'BBSI', 'KELYA', 'TBI', 'HSII', 'RHI']
# Peers for AIRS: ['CSTL', 'NVTA', 'CMAX', 'WGS', 'TLMD', 'PIII', 'AVAH', 'CVS']
# Peers for AEAE: ['CBAN', 'MPRA', 'FIAC', 'DPCS', 'SWAG', 'IREN', 'UTAA', 'CBRG', 'CMCA']
# Peers for CCTS: ['BSBK', 'OHAA', 'FRBN', 'EBMT', 'LION', 'PWOD']
# Peers for BFRI: ['NMTR', 'ANGN', 'EMMA', 'KALA', 'JNJ']
# Peers for PEGR: ['IOAC', 'BSRR', 'FNLC', 'FRST', 'LFAC', 'ACKIU', 'HLAH']
# Peers for SEDA: ['BGSX', 'LOCC', 'OPA']
# Peers for UDMY: ['CHGG', 'LAUR', 'LRN', 'ATGE', 'COUR', 'PRDO', 'TWOU', 'NRDY', 'BFAM']
# Peers for AURA: ['ATRA', 'VOR', 'DSGN', 'MGNX', 'EGRX', 'VNDA', 'CRBU', 'KOD', 'MGTX']
# Peers for DTC: ['RGR', 'JOUT', 'MCFT', 'SWBI', 'MPX', 'CLAR', 'SWIM', 'POWW', 'JAKK', 'HAS']
# Peers for FLNC: ['RUN', 'SHLS', 'ENS', 'CHPT', 'WIRE', 'ARRY', 'SPWR', 'VICR', 'EAF', 'EMR']
# Peers for FIAC: ['SWAG', 'IREN', 'UTAA', 'MPRA', 'CBRG', 'HBCP', 'AEAE', 'CBAN', 'DAOO']
# Peers for PCCT: ['DTRT', 'SVFB', 'CITE', 'FRON', 'USCT']
# Peers for BXSL: ['ORCC', 'AB', 'HLNE', 'FOCS', 'CNS', 'FHI', 'MAIN', 'STEP', 'BX']
# Peers for IOAC: ['PEGR', 'BSRR', 'FNLC', 'LFAC', 'FRST', 'BCBP', 'ACKIU']
# Peers for PHYT: ['WQGA', 'SCM']
# Peers for USCT: ['CMCA', 'FRON', 'DPCS', 'CITE']
# Peers for OHAA: ['CCTS', 'BSBK', 'FRBN', 'EBMT', 'FFNW', 'LION', 'DKDCA']
# Peers for INFA: ['DBX', 'CFLT', 'NTNX', 'CDK', 'COUP', 'GWRE', 'SMAR', 'CCCS', 'HCP', 'CTXS']
# Peers for DMAQ: ['PTRS', 'NBST', 'SCMA', 'MEOA', 'JMAC', 'FNCB', 'OFS', 'FNWD']
# Peers for MRAI: ['SLQT', 'HIPO', 'GOCO', 'EHTH', 'RELI', 'MMC']
# Peers for AIP: ['XPER', 'TUFN', 'ZFOX', 'TLS', 'IRNT', 'MSFT']
# Peers for RENT: ['PETS', 'WISH', 'PRTS', 'LE', 'BARK', 'GRPN', 'DLTH', 'DIBS', 'AKA', 'AMZN']
# No peers found for symbol ICNC
# No peers found for symbol MBSC
# No peers found for symbol PGSS
# Peers for ARIS: ['CWST', 'ABM', 'MEG', 'ECOL', 'HCCI', 'SP', 'HSC', 'BV', 'CECO', 'WM']
# Peers for XLO: ['PIRS', 'GALT', 'DBTX', 'TIL', 'XBIT', 'CELU', 'KRON', 'ATOS', 'VSTM']
# Peers for UTRS: ['CFMS', 'HSCS', 'AEMD', 'NDRA', 'BIOL', 'AVGR', 'HSDT', 'DYNT', 'ABT']
# Peers for XFIN: ['MPRA', 'AEAE', 'FIAC', 'CBAN', 'SWAG', 'IREN', 'UTAA', 'CBRG', 'HBCP', 'DPCS']
# Peers for PX: ['TSLX', 'GCMG', 'VRTS', 'NMFC', 'BSIG', 'ALTI', 'BBDC', 'WT', 'BX']
# Peers for PTLO: ['DNUT', 'CAKE', 'PLAY', 'EAT', 'JACK', 'DIN', 'SG', 'FWRG', 'BJRI', 'MCD']
# Peers for ENFN: ['ALKT', 'EVBG', 'MLNK', 'OLO', 'MODN', 'SEMR', 'PRO', 'CRNC', 'USER', 'CTXS']
# Peers for ENER: ['CDAQ', 'PBFS', 'BOCH', 'ATAK', 'DLCA', 'SHCA', 'GLRE']
# Peers for GTAC: ['VBNK', 'DALS', 'FHLT', 'APAC', 'VHNA', 'SMIH', 'GEEX', 'PRLH']
# No data found for symbol LZM
# Peers for VTYX: ['PBH', 'RVNC', 'HRMY', 'AXSM', 'CORT', 'AMLX', 'SUPN', 'PCRX', 'JNJ']
# Peers for COCO: ['KDP', 'CELH', 'COKE', 'FIZZ', 'ZVIA', 'JSDA', 'WTER', 'KO']
# No peers found for symbol ACAQ
# Peers for ESAC: ['APLD', 'LGVC', 'SFST', 'FWAC', 'SMMF', 'KINZ', 'TMKR', 'PEPL', 'BITF']
# Peers for WWAC: ['VII', 'SHAC', 'OSTR', 'ACNB']
# Peers for CYN: ['KLR', 'SDIG', 'RNWK', 'AWRE', 'NTWK', 'BTOG', 'SAI', 'CTXS']
# Peers for CNTX: ['PULM', 'AGRX', 'VYNE', 'ADIL', 'GRAY', 'VRPX', 'LABP', 'JNJ']
# Peers for SDIG: ['INUV', 'SRAX', 'KLR', 'RNWK', 'AWRE', 'CYN', 'NTWK', 'CTXS']
# Peers for NCAC: ['SBT', 'PUCK', 'BCBP', 'ONYX', 'LVRA', 'LFAC', 'IOAC']
# Peers for FBRT: ['TWO', 'CIM', 'LADR', 'RC', 'PMT', 'MFA', 'ARR', 'KREF', 'NYMT', 'NLY']
# Peers for SMAP: ['LIBY', 'DHAC', 'BREZ', 'FTII', 'GLLI', 'ROCG', 'PONO', 'KYCH', 'GMFI']
# Peers for FEXD: ['MTRY', 'FATP', 'LMST', 'GIAC', 'LVAC', 'TGVC', 'FCCO', 'WINV']
# Peers for PEPL: ['KINZ', 'SMMF', 'APTM', 'LCAA', 'OPRT', 'IPVI', 'LGVC', 'SPKB', 'XPDB']
# Peers for CDAQ: ['ENER', 'PBFS', 'BOCH', 'ATAK', 'DLCA', 'SHCA', 'GLRE']
# Peers for INKT: ['FBIO', 'AZYO', 'LGVN', 'RPHM', 'BSTG', 'ADVM', 'EVLO', 'LOGC', 'CKPT']
# Peers for AVHI: ['AMRB', 'FXNC', 'LARK', 'BTBT', 'IGTA']
# Peers for RBT: ['ASUR', 'LVOX', 'CLSK', 'UPLD', 'MAPS', 'SOUN', 'SMSI', 'VHC', 'CTXS']
# Peers for FNA: ['NUVA', 'ATRC', 'PRCT', 'ATEC', 'TMCI', 'NTUS', 'NVRO', 'LMAT', 'ABT']
# Peers for LUCD: ['PDEX', 'KNW', 'VANI', 'NVNO', 'AXDX', 'DCTH', 'VASO', 'ABT']
# Peers for IHS: ['MSGS', 'ATHM', 'WWE', 'USM', 'TGNA']
# Peers for ROSE: ['SAMG', 'NKSH', 'BNNR', 'TBNK', 'NHIC', 'BLNG', 'JAQC', 'ALPA']
# Peers for BMAC: ['KCGI', 'EVE', 'NETC', 'PACI', 'ATEK']
# Peers for TRIS: ['FLAG', 'BRD', 'KNSW', 'TMAC']
# Peers for XRTX: ['OPGN', 'GRAY', 'BPTS', 'NEPH', 'ARDS', 'IINN', 'CYTH', 'NSPR', 'FBRX']
# Peers for GTLB: ['ZS', 'GEN', 'MCFE', 'PATH', 'DLB', 'SAIL', 'MSP', 'MNDT', 'TENB', 'MSFT']
# Peers for AUGX: ['FORA', 'PEAR', 'AKLI', 'STRM', 'ICAD', 'CCLD', 'BTCY', 'CERN']
# Peers for AVDX: ['FLYW', 'VRRM', 'RELY', 'TTEC', 'TASK', 'PAYO', 'GSKY', 'CSGS', 'SABR', 'V']
# Peers for FATP: ['LMST', 'MTRY', 'FEXD', 'GIAC', 'LVAC', 'TGVC', 'FCCO', 'WINV']
# Peers for CLST: ['FFBW', 'BAFN', 'PNC']
# Peers for HCTI: ['ISPC', 'WORX', 'ACON', 'CERN']
# No peers found for symbol CRGO
# Peers for TCN: ['LXP', 'HASI', 'SITC', 'OUT', 'OFC', 'JBGS', 'DEA', 'BNL']
# Peers for CCSI: ['RIOT', 'LPSN', 'AVPT', 'MTTR', 'YEXT', 'MARA', 'EXFY', 'CTXS']
# No data found for symbol APLM
# No peers found for symbol LCW
# Peers for SAMA: ['HSAQ', 'RCAC', 'SSBK', 'AACI', 'TCFC', 'OXSQ', 'CVCY']
# Peers for PYXS: ['BCLI', 'HOWL', 'EIGR', 'FIXX', 'RZLT', 'TALS', 'SPRO', 'SLS', 'GRTX']
# Peers for CGTX: ['AQST', 'CLSD', 'HEPA', 'NRXP', 'JNJ']
# Peers for IXAQ: ['VLAT', 'ACNB', 'OSTR', 'LDHA', 'SHAC', 'VELO', 'NBN']
# Peers for LTH: ['MTN', 'PLNT', 'SEAS', 'FUN', 'BOWL', 'SIX', 'XPOF', 'RICK', 'FXLV']
# Peers for THRX: ['OCUL', 'NUVB', 'TARS', 'PHAT', 'NGM', 'VRCA', 'MRNS', 'JNJ']
# Peers for PBAX: ['PDLB', 'TRON', 'PANA', 'CSLM', 'GACQ', 'NRIM']
# Peers for NFYS: ['SLQT', 'SUAC', 'TRTL', 'ACRO', 'TWND']
# No data found for symbol BENF
# Peers for VLCN: ['HOG', 'LVWR', 'FUV']
# Peers for NVEI: ['LFUS', 'MKSI', 'CDK', 'COHR', 'LSCC', 'FIVN', 'AFRM']
# Peers for BHAC: ['VII', 'ARBG', 'SHAC', 'BPAC']
# No data found for symbol HUBC
# Peers for EXAI: ['ROIV', 'IMCR', 'MYOV', 'BCYC']
# Peers for GATE: ['DTOC', 'BYTS', 'IBCP', 'BCSA']
# Peers for MTRY: ['FEXD', 'FATP', 'LMST', 'GIAC', 'LVAC', 'TGVC', 'FCCO', 'WINV']
# Peers for FWRG: ['EAT', 'JACK', 'PTLO', 'DIN', 'SG', 'BJRI', 'DENN', 'CHUY', 'RUTH', 'MCD']
# Peers for TDCX: ['MWA', 'ERJ', 'ZIP', 'B', 'FTAI', 'GFF', 'DOOR', 'BBU', 'DAC', 'NPO']
# Peers for SLVM: ['VRS', 'CLW', 'NP', 'GLT']
# Peers for HPLT: ['ORIA', 'FICV', 'SWKH', 'PRLH', 'FHLT', 'DALS']
# Peers for OLPX: ['EL', 'COTY', 'BRBR', 'ELF', 'IPAR', 'BRBR', 'EPC', 'NUS', 'SKIN']
# Peers for ARTE: ['GEEX', 'MLAI', 'SMIH', 'VHNA', 'APAC', 'GHAC', 'GTAC']
# Peers for GFAI: ['SGRP', 'FPAY', 'TOPS', 'PATI', 'CVV', 'SIDU', 'APWC', 'ASTC', 'GRNQ', 'SGBX']
# Peers for IONM: ['IDXG', 'CVS']
# Peers for HCVI: ['GCBC', 'BWB', 'CSTR', 'RNER', 'MPB']
# Peers for NFGC: ['MMX']
# Peers for WRBY: ['WOOF', 'LESL', 'ODP', 'SBH', 'WINA', 'HIBB', 'HZO', 'BRLT', 'ULTA']
# Peers for BACA: ['FTEV', 'CNDA', 'PICC', 'MDH', 'EPWR', 'NFNT', 'ADEX', 'CURO']
# Peers for AMPL: ['QTWO', 'FORG', 'BTRS', 'RAMP', 'SUMO', 'ALKT', 'EVBG', 'MLNK', 'OLO', 'CTXS']
# Peers for CWAN: ['PYCR', 'AYX', 'WK', 'PWSC', 'DV', 'FRSH', 'BL', 'NCNO', 'PEGA', 'CTXS']
# Peers for DSAQ: ['WRAC', 'WNNR', 'IRRX', 'CORS', 'CAS']
# Peers for GIA: ['CLIM', 'STET', 'DMYS', 'INAQ', 'SCU']
# Peers for HLTH: ['SPNE', 'RBOT', 'AXGN', 'SRDX', 'TCMD', 'ZIMV', 'ARAY', 'ABT']
# Peers for BRLT: ['SBH', 'WRBY', 'WINA', 'HIBB', 'HZO', 'SPWH', 'BBW', 'TCS', 'BGFV', 'ULTA']
# Peers for THRN: ['USNA', 'WALD', 'VERU', 'HNST', 'NATR', 'EL']
# Peers for LOCC: ['SEDA', 'BGSX']
# Peers for ARBK: ['CREC', 'TGAA', 'ROC', 'CHPM', 'XPAX', 'HAIA', 'ORRF', 'CNGL', 'GLHA']
# Peers for VBNK: ['GTAC', 'DALS', 'FHLT', 'APAC', 'VHNA', 'SMIH', 'PRLH', 'SWKH', 'GEEX']
# Peers for STER: ['MAN', 'KFY', 'FA', 'UPWK', 'KFRC', 'HRT', 'BBSI', 'KELYA', 'TBI', 'RHI']
# Peers for SOVO: ['JJSF', 'THS', 'UTZ', 'HAIN', 'BRCC', 'BYND', 'JBSS', 'BGS', 'MDLZ']
# Peers for ESMT: ['BL', 'NCNO', 'PEGA', 'INST', 'CVT', 'NCR', 'ENV', 'SPT', 'RNG', 'CTXS']
# Peers for RELY: ['AFRM', 'EVOP', 'MQ', 'FLYW', 'VRRM', 'TTEC', 'TASK', 'AVDX', 'PAYO', 'V']
# Peers for AKA: ['BARK', 'RENT', 'GRPN', 'DLTH', 'DIBS', 'TDUP', 'RMBL', 'REAL', 'LVLU', 'AMZN']
# No peers found for symbol LUNR
# Peers for TOST: ['GPN', 'BR', 'FLT', 'SSNC', 'JKHY', 'WEX', 'CNXC', 'EXLS', 'EEFT', 'V']
# Peers for FRSH: ['AYX', 'WK', 'PWSC', 'DV', 'CWAN', 'BL', 'NCNO', 'PEGA', 'INST', 'CTXS']
# Peers for HHGC: ['HNNA', 'DILA', 'PPHP', 'MCAF', 'ASPA', 'GDST']
# Peers for JXN: ['APO', 'CRBG', 'EQH', 'VOYA', 'ALRS', 'BXLC']
# Peers for ACT: ['RKT', 'UWMC', 'NYCB', 'MTG', 'TFSL', 'RDN', 'COOP', 'PFSI', 'WSFS']
# Peers for TWKS: ['IT', 'EPAM', 'DOX', 'DXC', 'KD', 'PRFT', 'GDYN', 'HCKT', 'BBAI', 'IBM']
# Peers for BROS: ['YUM', 'DRI', 'DPZ', 'ARMK', 'TXRH', 'WING', 'WEN', 'PZZA', 'CBRL', 'MCD']
# Peers for DH: ['CERT', 'VCRA', 'GDRX', 'PHR', 'MDRX', 'SDGR', 'NXGN', 'AMWL', 'CERN']
# Peers for TYRA: ['ALLK', 'AKUS', 'CMPX', 'RDUS', 'ANIK', 'SGMO', 'SRRK', 'ARCT', 'SMMT']
# Peers for WINV: ['FCCO', 'TGVC', 'LVAC', 'GIAC', 'INTE', 'LMST', 'FATP', 'MTRY', 'FEXD']
# No data found for symbol ZAPP
# Peers for KTTA: ['TOVX', 'IBIO', 'NNVC', 'CLRB', 'BPTH', 'LIXT', 'INDP', 'APRE']
# Peers for PRCT: ['OMCL', 'TNDM', 'GKOS', 'NUVA', 'ATRC', 'ATEC', 'FNA', 'FNA', 'TMCI', 'ABT']
# No peers found for symbol SATX
# Peers for ONON: ['VAC', 'ARD', 'NCLH', 'PLNT', 'MUSA', 'BYD', 'PII', 'SKX', 'SON', 'TOL']
# No data found for symbol OCEA
# Peers for EZFL: ['IMPP', 'MMLP', 'SLNG', 'SNMP', 'EPD']
# Peers for GREE: ['SAI', 'BSQR', 'AVYA', 'SBIG', 'WOWI', 'SEAC', 'CTXS']
# Peers for SRAD: ['RMBS', 'SANM', 'SONO', 'CVLT', 'VICR', 'CVT', 'XRX', 'MXL']
# No peers found for symbol CACO
# Peers for SGML: ['TECK', 'LAC', 'IE']
# Peers for FLAG: ['SCUA', 'BRD', 'KNSW', 'RCFA', 'IRRX']
# Peers for FHLT: ['DALS', 'VBNK', 'GTAC', 'PRLH', 'SWKH', 'APAC', 'VHNA', 'SMIH']
# Peers for BNIX: ['BKSC', 'UBCP', 'EMCF', 'VBOC', 'LBBB', 'UBOH', 'SFBC']
# No peers found for symbol SLVR
# Peers for OXUS: ['APXI', 'TSBK', 'AFAC', 'DUNE', 'FNVT', 'PGRW', 'ASAX', 'THAC', 'PTMN']
# Peers for DWAC: ['SYBT', 'EFSC', 'LOB', 'HOPE', 'STEP', 'RNST', 'NWBI', 'TRMK', 'WABC', 'LPRO']
# Peers for GIPR: ['MDV', 'NYC', 'MDRR', 'SQFT', 'PRLE', 'PDNLB', 'WPC']
# Peers for INAQ: ['SCU', 'DMYS', 'CLIM', 'GIA', 'STET']
# Peers for INCR: ['BVXV', 'TARO', 'MDWD', 'SLGL']
# Peers for CNDA: ['PICC', 'MDH', 'FTEV', 'EPWR', 'NFNT', 'BACA', 'ADEX', 'PACI']
# Peers for OMQS: ['RSSS', 'DPSI', 'VRAR', 'CSPI', 'CTM', 'IBM']
# Peers for DDI: ['GRVY']
# Peers for PET: ['CSV', 'STON', 'STON', 'WW', 'BODY', 'RGS', 'XWEL', 'SPGZ']
# Peers for BRAG: ['ELYS']
# Peers for SQL: ['ISO', 'SNCE', 'PBIO', 'INIS', 'APDN', 'TMO']
# Peers for ICCM: ['NNOX', 'DRTS']
# Peers for CCAI: ['GREE', 'CLOE', 'HYW', 'MLAC', 'MITA', 'NECB', 'ARYE', 'RAM']
# Peers for SWSS: ['MEAC', 'BSVN', 'ALOR', 'CVLY', 'SSSS', 'CENQ']
# Peers for RNXT: ['DYAI', 'IMPL', 'CRVS', 'SRZN', 'QNCX', 'ELDN', 'EQ', 'SIOX']
# Peers for KCGI: ['BMAC', 'EVE', 'NETC', 'PACI', 'ATEK']
# No peers found for symbol AACI
# Peers for DRMA: ['TTOO', 'ONCS', 'KRBP', 'ENSC', 'FWBI']
# No data found for symbol VGAS
# Peers for JAQC: ['TBNK', 'CVCY', 'OXSQ', 'NKSH', 'SAMG', 'ROSE', 'SSBK']
# Peers for VQS: ['SEAC', 'IDN', 'PRSO', 'NTWK', 'DTSS', 'GLG', 'CSPI']
# Peers for DATS: ['QUMU', 'FOXO', 'MARK', 'AUUD', 'EVOL', 'CTXS']
# No data found for symbol JTAI
# Peers for PPHP: ['MCAF', 'GDST', 'HHGC', 'HNNA', 'DILA', 'NOVV', 'ASPA']
# Peers for SSBK: ['PCB', 'BCML', 'TCBX', 'PLBC', 'USCB', 'PNC']
# No peers found for symbol AWIN
# No data found for symbol HHRS
# Peers for DFLI: ['LYTS', 'FTCI', 'SKYX', 'GWH', 'EOSE', 'BEEM', 'AMSC', 'KULR', 'EMR']
# Peers for VCXA: ['SKYA', 'GLHA', 'CNGL', 'HAIA', 'EHTH', 'XPAX', 'FRSG', 'TGAA']
# No data found for symbol LVRO
# Peers for PMCB: ['BOLT', 'GLTO', 'CADL', 'TCRX', 'LTRN', 'LPTX', 'UBX', 'RCOR', 'MBIO']
# Peers for ASPA: ['DILA', 'HNNA', 'HHGC', 'VBFC', 'PPHP', 'MCAF', 'GDST']
# Peers for OABI: ['CYRX', 'BLFS', 'SLGC', 'MXCT', 'AKYA', 'NSTG', 'QTRX', 'BNGO', 'CDXS', 'TMO']
# Peers for ELYM: ['XLO', 'CELU', 'KRON', 'ATOS', 'VSTM', 'ARMP', 'PRDS', 'GLYC', 'CLNN']
# Peers for CRDL: ['GNPX', 'MACK', 'SIEN', 'TCRX', 'ICCM', 'ABVC', 'HARP', 'ANEB', 'HCWB']
# Peers for GPOR: ['TALO', 'CRGY', 'MNRL', 'ESTE', 'ROCC', 'GRNT', 'DMLP', 'KRP', 'COP']
# Peers for DPRO: ['FLUX', 'GTEC', 'ENG', 'POLA', 'BWEN', 'FTEK', 'TAYD', 'YGMZ', 'PXS']
# No data found for symbol TYGO
# Peers for NOVV: ['GDST', 'MCAF', 'PPHP', 'HHGC', 'HNNA', 'DILA']
# No peers found for symbol WEST
# Peers for IVVD: ['LIAN', 'GRTS', 'JSPR', 'STTK', 'GLSI', 'PBYI', 'TNYA', 'PRAX', 'ORIC']
# Peers for FYBR: ['VZ', 'T', 'RADI', 'IDT', 'ATNI', 'CNSL', 'LICT', 'OOMA']
# Peers for EWCZ: ['HRB', 'TMX', 'MCW', 'VVNT', 'FTDR', 'ROVR', 'CSV', 'STON', 'STON', 'SPGZ']
# Peers for GSD: ['OFED', 'AEHA', 'CFBK', 'FXCO', 'EUCR', 'CZWI', 'FRAF']
# Peers for OBT: ['FNLC', 'ACNB', 'MVBF', 'LEVL', 'BSRR', 'CVCY', 'NRIM', 'PNC']
# Peers for CYBN: ['MIST']
# No data found for symbol LNZA
# Peers for VSCO: ['TJX', 'ROST', 'BURL', 'GPS', 'FL', 'AEO', 'URBN', 'BOOT', 'BKE']
# Peers for HWEL: ['WULF', 'GVCI', 'BCML', 'PCSB', 'MEKA', 'ADAL', 'FANH', 'ACAB', 'FGBI']
# Peers for GXO: ['UPS', 'FDX', 'EXPD', 'CHRW', 'HUBG', 'AAWW', 'FWRD', 'ATSG', 'RLGT']
# Peers for RANI: ['THRX', 'VRCA', 'MRNS', 'AVIR', 'RAIN', 'BTMD', 'SCPH', 'JNJ']
# Peers for TNYA: ['JSPR', 'STTK', 'GLSI', 'IVVD', 'PBYI', 'PRAX', 'ORIC', 'OVID', 'GTHX']
# Peers for OMGA: ['GLUE', 'OTLK', 'SVRA', 'RLYB', 'VAXX', 'VYGR', 'HRTX', 'LRMR']
# Peers for DOLE: ['UTZ', 'SKIL', 'DDL', 'BIG', 'ELF', 'FDP', 'AGRO', 'HIMS', 'USNA', 'LND']
# No data found for symbol ZLS
# Peers for IMRX: ['TCRT', 'BCAB', 'CMRX', 'ANVS', 'DTIL', 'CUE', 'ANIX', 'SESN']
# Peers for INAB: ['TARA', 'ACXP', 'ORGS', 'TCON', 'MBRX', 'DYAI', 'IMPL', 'CRVS', 'SRZN']
# Peers for MXCT: ['CTKB', 'ADPT', 'CYRX', 'BLFS', 'SLGC', 'AKYA', 'OABI', 'NSTG', 'QTRX', 'TMO']
# Peers for RXST: ['KIDS', 'UFPT', 'CERS', 'OSUR', 'LUNG', 'SMTI', 'UTMD', 'TELA', 'SDC']
# Peers for MTAL: ['VEL', 'CURO', 'ACAQ']
# Peers for COOK: ['WHR', 'CRCT', 'IRBT', 'WEBR', 'HBB', 'ATER']
# Peers for NUVL: ['SWTX', 'IRWD', 'BBIO', 'KYMR', 'VCYT', 'BCRX', 'PRME', 'SNDX', 'MORF']
# Peers for IMAQ: ['AEAC', 'MYFW', 'CFFE', 'BIOS', 'THCP', 'NRAC', 'ESQ', 'BWC']
# Peers for RSKD: ['SPNS', 'CLBT', 'WKME', 'MGIC', 'PGY', 'SMWB']
# Peers for NOGN: ['HOUR', 'GROV', 'POL', 'BOXD', 'IPW', 'IMBI', 'ID', 'AMZN']
# Peers for ICVX: ['ALPN', 'TRDA', 'BMEA', 'KPTI', 'STOK', 'ACET', 'PMVP', 'STRO', 'ACRV']
# Peers for HOOD: ['GS', 'IBKR', 'RJF', 'LPLA', 'JEF', 'SF', 'HLI', 'EVR', 'FRHC', 'MS']
# Peers for RLYB: ['HUMA', 'OYST', 'GLUE', 'OTLK', 'SVRA', 'VAXX', 'OMGA', 'VYGR', 'HRTX']
# Peers for SNPO: ['SONO', 'VZIO', 'GPRO', 'VOXX', 'VUZI', 'UEIC', 'KOSS', 'MSN']
# Peers for MLNK: ['RAMP', 'SUMO', 'AMPL', 'ALKT', 'EVBG', 'OLO', 'MODN', 'ENFN', 'SEMR', 'CTXS']
# Peers for PWSC: ['BOX', 'YOU', 'PYCR', 'AYX', 'WK', 'DV', 'CWAN', 'FRSH', 'BL', 'CTXS']
# No data found for symbol SEPA
# Peers for APTM: ['LCAA', 'OPRT', 'PEPL', 'IPVI', 'KINZ', 'SPKB', 'SMMF', 'XPDB', 'ARRW']
# Peers for DUOL: ['BFAM', 'LOPE', 'GHC', 'HMHC', 'STRA', 'CHGG', 'LAUR', 'LRN', 'ATGE']
# Peers for CADL: ['CRIS', 'ENOB', 'IMNM', 'BOLT', 'GLTO', 'TCRX', 'LTRN', 'PMCB', 'LPTX']
# Peers for WRAC: ['WNNR', 'DSAQ', 'IRRX', 'RCFA', 'KNSW']
# No data found for symbol CTCX
# Peers for SOPH: ['XERS', 'MCRB', 'GBIO', 'AERI', 'VRNA', 'PHAT', 'ZYXI', 'BNR']
# Peers for XPOF: ['SEAS', 'LTH', 'FUN', 'BOWL', 'SIX', 'RICK', 'FXLV', 'AGAE', 'HOFV', 'MTN']
# Peers for GAMB: ['HNST', 'STKS', 'ISPO', 'BGFV', 'GRWG', 'MPAA', 'SGC', 'INSE', 'DXLG']
# Peers for CNM: ['FAST', 'URI', 'WSO', 'WCC', 'SITE', 'UNVR', 'AIT', 'MSM', 'AL', 'GWW']
# Peers for CTKB: ['SHC', 'SYNH', 'MRVI', 'AZTA', 'PACB', 'ADPT', 'CYRX', 'BLFS', 'SLGC', 'TMO']
# Peers for USCB: ['BCML', 'SSBK', 'TCBX', 'PLBC', 'INBK', 'NKSH', 'ORRF', 'PKBK', 'PNC']
# Peers for OB: ['KIND', 'VMEO', 'EVER', 'SST', 'FUBO', 'BZFD', 'TRUE', 'DHX', 'LTRPA', 'GOOGL']
# Peers for INST: ['CWAN', 'FRSH', 'BL', 'NCNO', 'PEGA', 'CVT', 'ESMT', 'NCR', 'ENV', 'CTXS']
# Peers for ZVIA: ['CELH', 'COKE', 'FIZZ', 'COCO', 'WTER', 'JSDA', 'REED', 'KO']
# Peers for RYAN: ['MMC', 'AJG', 'BRO', 'BRP', 'HGTY', 'GSHD', 'SLQT', 'HIPO', 'GOCO']
# Peers for BASE: ['CCSI', 'YEXT', 'MARA', 'EXFY', 'ECOM', 'EGHT', 'AVLR', 'CTXS']
# Peers for ZENV: ['STIX']
# Peers for ABSI: ['BIVI', 'ABOS', 'ATXS', 'NKTX', 'LCTX', 'OCGN', 'LIAN', 'GRTS', 'JSPR']
# Peers for PFTA: ['VPCB', 'GFGD', 'WHF', 'HIVE', 'ROOT', 'GGAA', 'TCBX']
# Peers for PYCR: ['FIVN', 'APPF', 'NEWR', 'BOX', 'YOU', 'AYX', 'WK', 'PWSC', 'DV', 'CTXS']
# Peers for VEEE: ['JAKK', 'ESCA', 'AOUT', 'NLS', 'FRZA', 'HAS']
# Peers for CULL: ['HMNF', 'MCBK', 'BYFC', 'FOA', 'MGYR', 'WAYN', 'TCBC', 'RKT']
# Peers for TCBC: ['FOA', 'CULL', 'MGYR', 'WAYN', 'WBBW', 'HVBC', 'CLST', 'RKT']
# Peers for VTEX: ['WEJO']
# Peers for LAW: ['ONTF', 'GTYH', 'SSTI', 'MITK', 'RMNI', 'DMRC', 'CIFR', 'BLND', 'BNFT', 'CTXS']
# Peers for KLTR: ['NN', 'PRCH', 'CCRD', 'VERI', 'APLD', 'EGAN', 'DSP', 'ASUR', 'CTXS']
# Peers for CLAY: ['WTMA', 'CIZN', 'KACL', 'AFBI', 'SFBC', 'UBOH']
# Peers for VAL: ['NBR']
# Peers for CLOE: ['HYW', 'MLAC', 'CCAI', 'GREE', 'MITA', 'NECB', 'RAM', 'APMI']
# Peers for NABL: ['RPD', 'CVLT', 'PRGS', 'PING', 'FROG', 'SWI', 'ZUO', 'ATEN', 'ADEA', 'MSFT']
# Peers for TRTL: ['ACRO', 'SLQT', 'NFYS', 'SUAC', 'TWND', 'MACC']
# Peers for HCWB: ['ADVM', 'EVLO', 'LOGC', 'CKPT', 'VIRX', 'ASMB', 'GNPX', 'IMUC', 'PASG']
# No data found for symbol VFS
# Peers for BRDG: ['APAM', 'GBDC', 'VCTR', 'AMK', 'HTGC', 'GSBD', 'OCSL', 'TSLX', 'BX']
# Peers for BLND: ['MITK', 'RMNI', 'LAW', 'DMRC', 'CIFR', 'BNFT', 'WEAV', 'CTXS']
# Peers for STVN: ['OSH', 'AMN', 'SGFY', 'INSP', 'BHC', 'DNA', 'CNMD', 'MPLN', 'TDOC', 'HAE']
# Peers for RGC: ['BLTE', 'ACLX', 'ESPR', 'TYRA', 'KOD', 'GLUE', 'OPT', 'OTLK', 'ABUS', 'MNMD']
# Peers for BLFY: ['GCBC', 'GHI', 'BWB', 'WSBF', 'NASB', 'HBCP', 'VEL', 'SBT', 'FMCC', 'RKT']
# Peers for TCBS: ['NSTS', 'KFFB', 'FSEA', 'IOR', 'CNNB', 'RKT']
# Peers for APAC: ['VHNA', 'SMIH', 'GTAC', 'VBNK', 'GEEX', 'DALS', 'FHLT', 'ARTE']
# Peers for TCRX: ['ENOB', 'IMNM', 'BOLT', 'GLTO', 'CADL', 'LTRN', 'PMCB', 'LPTX', 'UBX']
# Peers for ERAS: ['ARDX', 'FATE', 'HLVX', 'ZYME', 'CHRS', 'LYEL', 'BLUE', 'AVEO', 'MRSN']
# Peers for PBBK: ['EQFN', 'BCTF', 'HLFN', 'HCBC', 'MSVB', 'CTUY', 'LOGN', 'EFBI', 'RKT']
# Peers for PECO: ['NNN', 'BRX', 'ADC', 'SRC', 'KRG', 'SITC', 'MAC', 'SKT', 'UE', 'O']
# No data found for symbol SHCO
# Peers for KITT: ['MVST', 'HYZN', 'MLR', 'CVGI', 'TWIN', 'XOS', 'MNTX', 'IDEX', 'CAT']
# Peers for UPTD: ['ACBA', 'BOTJ', 'KFFB', 'BCOW', 'CLST', 'CFSB', 'TURN']
# Peers for QUBT: ['EMBK', 'SNCR', 'KLDI', 'REKR', 'AEYE', 'CTXS']
# Peers for SERA: ['CADL', 'ISR', 'VXRT', 'ETTX', 'MTNB', 'PIRS', 'GALT', 'DBTX', 'TIL']
# Peers for SGHT: ['VREX', 'CUTR', 'SIBN', 'AORT', 'ANGO', 'ZYXI', 'APEN', 'IRMD', 'SENS', 'ABT']
# Peers for RPID: ['CDXC', 'BLI', 'CSBR', 'MIRO', 'TBIO', 'ISO', 'SNCE', 'PBIO', 'INIS', 'TMO']
# No data found for symbol ZURA
# Peers for IINN: ['GCTK', 'CHEK', 'MDGS']
# Peers for UNCY: ['NBSE', 'CBIO', 'AYLA', 'ADXS', 'SILO', 'RNAZ']
# Peers for SLI: ['IE', 'TECK']
# Peers for BHG: ['FG', 'TRUP', 'NWLI', 'OSCR', 'IHC', 'KCLI', 'CIA', 'VERY', 'MET']
# No peers found for symbol MRT
# Peers for SNTG: ['QH']
# Peers for ACRO: ['TRTL', 'SLQT', 'NFYS', 'SUAC', 'TWND', 'MACC']
# Peers for RNAZ: ['CBIO', 'AYLA', 'ADXS', 'UNCY', 'SILO', 'ALRN', 'WINT']
# Peers for ALCC: ['CCV', 'FSNB', 'GHLD', 'MIT']
# Peers for AGRI: ['VFF']
# Peers for VEV: ['LEV']
# Peers for MITQ: ['GAIA', 'FGH', 'DLPN', 'MGAM', 'DIS']
# Peers for NYXH: ['SNCE', 'IVA', 'VRDN', 'RXST', 'MGTX', 'IXHL', 'NOTV', 'RPTX', 'OGI', 'SGHT']
# No peers found for symbol HEPS
# Peers for DTM: ['NFE', 'HESM', 'SHLX', 'ENLC', 'AM', 'KNTK', 'ETRN', 'PAGP', 'CEQP', 'EPD']
# Peers for HIVE: ['ROOT', 'TCBX', 'VPCB', 'PFTA', 'CIVB', 'RCLF']
# Peers for FICV: ['HPLT', 'ORIA', 'SWKH', 'PRLH', 'NVAC', 'FHLT']
# Peers for CURV: ['CHS', 'GCO', 'PLCE', 'ZUMZ', 'DXLG', 'JILL', 'TLYS', 'CTRN', 'CATO', 'TJX']
# Peers for DNUT: ['WEN', 'PZZA', 'CBRL', 'SHAK', 'BLMN', 'CAKE', 'PLAY', 'EAT', 'JACK', 'MCD']
# Peers for EVCM: ['VERX', 'ZETA', 'IDCC', 'ETWO', 'AGYS', 'QTWO', 'FORG', 'BTRS', 'RAMP', 'CTXS']
# No peers found for symbol WAVE
# Peers for VRAR: ['CTG', 'PFSW', 'MLGO', 'CSPI', 'RSSS', 'CISO', 'DPSI', 'CTM', 'OMQS', 'IBM']
# Peers for ABOS: ['FENC', 'CMPI', 'KNTE', 'PDSB', 'BIVI', 'ATXS', 'NKTX', 'LCTX', 'ABSI']
# Peers for YOU: ['ALTR', 'FIVN', 'APPF', 'NEWR', 'BOX', 'PYCR', 'AYX', 'WK', 'PWSC', 'CTXS']
# Peers for IAS: ['TTD', 'OMC', 'IPG', 'STGW', 'MGNI', 'TTGT', 'THRY', 'PUBM', 'ADV']
# Peers for AKLI: ['OPRX', 'BBLN', 'TRHC', 'FORA', 'PEAR', 'STRM', 'ICAD', 'AUGX', 'CCLD', 'CERN']
# Peers for PROK: ['ACAD', 'VIR', 'ISEE', 'BEAM', 'INSM', 'MRTX', 'SAGE', 'TGTX', 'BPMC']
# Peers for MCAF: ['PPHP', 'GDST', 'HHGC', 'HNNA', 'DILA', 'NOVV', 'ASPA']
# Peers for THCP: ['NRAC', 'ESQ', 'BWC', 'UNTY', 'AEAC', 'IMAQ', 'PFHD', 'ITIC']
# Peers for CPOP: ['MMV', 'LIZI', 'KUKE']
# Peers for AVTE: ['EBS', 'ETNB', 'JANX', 'ITOS', 'EDIT', 'MCRB', 'ALVR', 'FDMT']
# Peers for XMTR: ['DASH', 'CHWY', 'ETSY', 'W', 'RVLV', 'POSH', 'OSTK', 'QRTEA', 'FLWS', 'AMZN']
# Peers for S: ['MSP', 'MNDT', 'TENB', 'QLYS', 'KNBE', 'TDC', 'APPN', 'VRNS', 'RPD', 'MSFT']
# ...
# Peers for CBD: ['CWH', 'ANF', 'GRBK', 'HLLY', 'GES', 'LZB', 'DIN', 'DBI', 'EAT', 'CAL']
# Peers for BMA: ['CPUH', 'FINV', 'LDI']
# Peers for FSV: ['CIGI', 'PECO', 'OPEN', 'PCH', 'SBRA', 'UNIT', 'NMRK', 'ROIC']
# Peers for ASX: ['TYL', 'LDOS', 'HUBS', 'UI', 'PLTR', 'PAYC', 'BR', 'NET', 'GDDY', 'BILL']
# Peers for KRMD: ['IIN', 'CVRX', 'CLPT', 'ASXC', 'STXS', 'XAIR', 'SMLR', 'ABT']
# Peers for FXNC: ['PBHC', 'UNB', 'PNC']
# Peers for POCI: ['OWLT', 'SSKN', 'PAVM', 'ICU', 'BMRA', 'DXR', 'ABT']
# Peers for ACFN: ['AATC', 'ASTC', 'VRME', 'ELSE', 'DGLY', 'KEYS']
# Peers for ACHV: ['GANX', 'AQB', 'HOOK', 'APLT', 'ICCC', 'MGTA', 'ALZN', 'OCX', 'ISR']
# Peers for HPTO: ['SOFO', 'BLIN', 'BLBX', 'CTXS']
# Peers for FLUX: ['DFLI', 'EOSE', 'BEEM', 'AMSC', 'KULR', 'ADN', 'NEOV', 'IPWR', 'ULBI', 'EMR']
# Peers for CEQP: ['NFE', 'ENLC', 'AM', 'DTM', 'KNTK', 'PAGP', 'ETRN', 'EE', 'HEP', 'EPD']
# No data found for symbol TPCS
# Peers for OPRX: ['CNVY', 'HCAT', 'MPLN', 'CPSI', 'CSLT', 'BBLN', 'TRHC', 'FORA', 'PEAR', 'CERN']
# Peers for AVGR: ['AEMD', 'NDRA', 'BIOL', 'UTRS', 'HSDT', 'DYNT', 'INVO', 'NAOV', 'ABT']
# Peers for GAU: ['TRX', 'CMT', 'VGZ', 'FURY', 'ASM', 'FRD', 'ITRG', 'AUMN', 'AXU']
# Peers for PAAS: ['UFPI', 'SSRM', 'BCPC', 'MEOH', 'IOSP', 'WDFC', 'RGLD', 'GPRE', 'KALU', 'SGML']
# Peers for CRSP: ['MLTX', 'VECT', 'ACIU', 'ADCT']
# Peers for GBCS: ['UHT', 'HTIA', 'GMRE', 'DHC', 'WELL']
# Peers for CSBR: ['CDXC', 'NOTV', 'TBIO', 'OMIC', 'TKNO', 'RPID', 'BLI', 'MIRO', 'SNCE', 'TMO']
# Peers for TTNP: ['ALIM', 'COCP', 'LABP', 'ADIL', 'GRAY', 'PULM', 'CNTX', 'JNJ']
# Peers for PRPO: ['PMD', 'AMS', 'OTRK', 'CTEK', 'NVOS', 'CVS']
# Peers for AMEH: ['GH', 'AMED', 'NEO', 'AGTI', 'HIMS', 'ADUS', 'TVTY', 'RDNT', 'CVS']
# Peers for USRM: ['DRMA', 'ENSC', 'FWBI', 'OPGN', 'ATRX', 'SCPS']
# Peers for BLNK: ['FCEL', 'STEM', 'SES', 'THR', 'AMOT', 'AMPX', 'POWL', 'PLPC', 'LYTS', 'EMR']
# Peers for RVYL: ['STCN', 'USIO', 'BMTX', 'APCX', 'OLB', 'XELA', 'V']
# Peers for BLBX: ['SOFO', 'BLIN', 'HPTO', 'SLNH', 'SASI', 'CTXS']
# Peers for GMBL: ['EJH', 'FORD', 'PIK', 'BTBD', 'SECO', 'RAVE', 'AUVI']
# No data found for symbol NB
# Peers for GDRZF: ['DC', 'GORO', 'HYMC', 'VGZ', 'NEM']
# Peers for GWAV: ['TOMZ', 'AWX', 'JAN', 'WM']
# Peers for PED: ['EPSN', 'PHX', 'AXAS', 'COP']
# Peers for USIO: ['ALJJ', 'STCN', 'BMTX', 'APCX', 'RVYL', 'V']
# Peers for SCWX: ['NABL', 'SWI', 'ZUO', 'ATEN', 'ADEA', 'OSPN', 'XPER', 'TUFN', 'MSFT']
# Peers for SND: ['TUSK', 'CCLP', 'KLXE', 'EXTN', 'NGS', 'GEOS', 'GIFI', 'NCSM', 'PFIE', 'SLB']
# Peers for NTNX: ['MANH', 'ZEN', 'IOT', 'DBX', 'CFLT', 'CDK', 'COUP', 'INFA', 'GWRE', 'CTXS']
# Peers for GOLF: ['PII', 'MAT', 'BC', 'PTON', 'MODG', 'YETI', 'VSTO', 'MBUU', 'RGR', 'HAS']
# Peers for INSW: ['DTM', 'KNTK', 'ETRN', 'PAGP', 'CEQP', 'HEP', 'EE', 'RTLR', 'DKL', 'EPD']
# Peers for BL: ['WK', 'PWSC', 'DV', 'CWAN', 'FRSH', 'NCNO', 'PEGA', 'INST', 'CVT', 'CTXS']
# Peers for AA: ['ARNC', 'KALU', 'CENX', 'TG', 'NORNQ']
# Peers for OTLK: ['RCEL', 'PGEN', 'HUMA', 'OYST', 'GLUE', 'SVRA', 'RLYB', 'VAXX', 'OMGA']
# Peers for VVV: ['DOW', 'WLK', 'OLN', 'CBT', 'TROX', 'MATV', 'KRO', 'ASIX', 'PCT']
# No data found for symbol CRVO
# Peers for XBIO: ['BIOC', 'KTRA', 'PTIX', 'TRVN', 'BLCM', 'PBLA', 'SNPX']
# Peers for MRKR: ['ERNA', 'HGEN', 'CDAK', 'FNCH', 'TPST', 'SONN', 'YTEN', 'BWV', 'ACGN']
# Peers for ADNT: ['APTV']
# Peers for SNAP: ['GOOGL', 'META', 'TWTR', 'PINS', 'MTCH', 'ZI', 'IAC', 'BMBL', 'ZD']
# Peers for SENS: ['ANGO', 'SGHT', 'ZYXI', 'APEN', 'IRMD', 'BFLY', 'INGN', 'SPNE', 'RBOT', 'ABT']
# Peers for SRG: ['DBRG', 'KW', 'WE', 'FRPH', 'ARL', 'TCI', 'NEN']
# Peers for DSKE: ['RXO', 'MRTN', 'HTLD', 'ULH', 'PTSI', 'CVLG', 'TSP', 'USAK', 'YELL', 'UBER']
# Peers for TCMD: ['RBOT', 'AXGN', 'SRDX', 'HLTH', 'ZIMV', 'ARAY', 'ZOM', 'ABT']
# Peers for PI: ['POWI', 'RMBS', 'SYNA', 'DIOD', 'AMBA', 'MXL', 'SITM', 'SMTC', 'INDI', 'NVDA']
# Peers for RETA: ['AMLX', 'SUPN', 'PCRX', 'TLRY', 'ARVN', 'AMPH', 'PLRX', 'ZGNX', 'JNJ']
# Peers for NTB: ['STC', 'ARGO', 'GDOT', 'AMK', 'TSLX']
# Peers for MYSZ: ['CETX', 'MTEK', 'KSPN', 'SONM', 'EZFL', 'UTME', 'LEDS', 'CUEN', 'OBLG']
# Peers for AQB: ['SPRB', 'MAIA', 'ONCT', 'GANX', 'HOOK', 'APLT', 'ICCC', 'ACHV']
# Peers for TRVG: ['LOV']
# Peers for NNDM: ['WLDS', 'OTIVF']
# Peers for ADAP: ['CMPS', 'CNTA', 'AUTL', 'ROIV']
# Peers for RMNI: ['AMSWA', 'ONTF', 'GTYH', 'SSTI', 'MITK', 'LAW', 'DMRC', 'CIFR', 'BLND', 'CTXS']
# Peers for PRPL: ['TPX', 'MHK', 'LEG', 'LZB', 'ETD', 'LOVE', 'CSPR', 'HOFT', 'BSET']
# Peers for WSC: ['PWR', 'ACM', 'EME', 'MTZ', 'VMI', 'MDU', 'APG', 'FIX', 'FLR']
# Peers for SNDX: ['KYMR', 'VCYT', 'NUVL', 'BCRX', 'PRME', 'MORF', 'CPRX', 'RNA', 'MYGN']
# Peers for CRVS: ['TNXP', 'MAIA', 'SURF', 'AXLA', 'CRBP', 'TARA', 'CDIO', 'ORGS']
# Peers for AIRG: ['ROG', 'KN', 'LWLG', 'BELFA', 'AKTS', 'CPSH', 'DYSL', 'TMPO', 'APH']
# Peers for PTGX: ['ALBO', 'ALLO', 'COGT', 'VKTX', 'MIRM', 'BTAI', 'IMGN', 'IDYA', 'ICPT']
# Peers for ANAB: ['NVAX', 'ADMA', 'ALEC', 'SANA', 'NWBO', 'CTIC', 'EBS', 'ETNB', 'JANX']
# Peers for MSBI: ['MCB', 'CAC', 'FFIC', 'CCBG', 'CCB', 'MBWM', 'FMNB', 'THFF', 'PNC']
# Peers for SRTS: ['CTSO', 'EAR', 'NPCE', 'SONX', 'DRIO', 'FONR', 'ELMD', 'APYX', 'PLSE', 'ABT']
# Peers for CLSD: ['RLMD', 'PVCT', 'AQST', 'CGTX', 'HEPA', 'JNJ']
# Peers for SYRS: ['TALS', 'SPRO', 'SLS', 'GRTX', 'SNTI', 'BDTX', 'BYSI', 'CRDF']
# Peers for ELF: ['EL', 'COTY', 'BRBR', 'IPAR', 'OLPX', 'BRBR', 'EPC', 'NUS', 'SKIN']
# Peers for POLA: ['BWEN', 'PSIX', 'OPTT', 'CGRN', 'PPSI', 'BE']
# Peers for NRBO: ['CRBP', 'CYCC', 'NERV', 'NEXI', 'SNGX', 'RUBY', 'IMNN', 'CYTH', 'CDIO']
# Peers for TRTN: ['TGH']
# Peers for BBU: ['DAC', 'VLRS', 'GFF', 'AIR', 'SPCE', 'CRS', 'B', 'HNI', 'SFL', 'ERJ']
# Peers for YUMC: ['LKNCY']
# Peers for ACIU: ['MLTX', 'VECT', 'ADCT', 'CRSP']
# Peers for CNDT: ['MMS', 'VRRM', 'TTEC', 'CSGS', 'TASK', 'IBEX', 'SRT', 'ALJJ', 'STCN', 'BR']
# Peers for PRTH: ['IIIV', 'CASS', 'IBEX', 'CTLP', 'PAYS', 'SRT', 'V']
# Peers for REVG: ['GBX', 'ASTE', 'PTRA', 'SHYF', 'PLOW', 'MTW', 'BLBD', 'HYLN', 'MVST', 'CAT']
# Peers for NEX: ['CHX', 'WFRD', 'WHD', 'ACDC', 'LBRT', 'TDW', 'USAC', 'OII', 'RES', 'SLB']
# Peers for CTSO: ['XAIR', 'SMLR', 'STIM', 'EAR', 'NPCE', 'SONX', 'DRIO', 'ABT']
# Peers for JXJT: ['DOGZ', 'EVKG', 'KGJI']
# Peers for MPVDF: ['ERLFF', 'NANX']
# Peers for CLSK: ['KLTR', 'CCRD', 'EGAN', 'BLND', 'APLD', 'NN', 'VERI', 'CTXS']
# Peers for PR: ['RRC', 'MTDR', 'PDCE', 'MUR', 'SWN', 'CIVI', 'CHRD', 'VNOM', 'MGY', 'COP']
# Peers for EVBG: ['BTRS', 'RAMP', 'SUMO', 'AMPL', 'ALKT', 'MLNK', 'OLO', 'MODN', 'ENFN', 'CTXS']
# Peers for QNRX: ['PHGE', 'VBLT', 'SPRC', 'TIKRF', 'ROSGQ']
# Peers for GMRE: ['LTC', 'CHCT', 'UHT', 'HTIA', 'DHC', 'GBCS', 'WELL']
# Peers for GDC: ['CLWT']
# Peers for SELB: ['AMAM', 'EPZM', 'XOMA', 'CABA', 'GBIO', 'FHTX', 'ATNM', 'FENC', 'CMPI']
# Peers for ORGO: ['PMVP', 'STRO', 'ACRV', 'INO', 'VERA', 'RCEL', 'PGEN', 'HUMA', 'OYST']
# Peers for ICHR: ['COHU', 'UCTT', 'PDFS', 'PLAB', 'VECO', 'AEHR', 'ACMR', 'CYBE', 'AMAT']
# Peers for MRAM: ['AOSL', 'CEVA', 'SKYT', 'NVEC', 'TGAN', 'KOPN', 'RGTI', 'PXLW', 'EMAN', 'NVDA']
# Peers for PLX: ['KMDA', 'CLGN', 'GMDA', 'ENLV']
# No peers found for symbol ELLO
# Peers for ENIC: ['NWN', 'SJW', 'NRGV', 'ARIS', 'LFG', 'PAM', 'CPK', 'AMPS', 'SPH', 'AZRE']
# Peers for MESO: ['NRIX', 'IMVT', 'ATRA', 'MXCT', 'IMTX', 'KPTI', 'NAUT', 'TSVT', 'OPRX', 'JANX']
# Peers for OR: ['MTX', 'AG', 'KRO', 'BVN', 'SLVM', 'CSTM', 'SCL']
# Peers for UL: ['ABTI']
# Peers for NOMD: ['BRBR', 'SPB', 'SAM', 'BRFS', 'GHC', 'ASAI', 'RLX', 'NTCO', 'CCU', 'UNFI']
# Peers for KRP: ['ESTE', 'ROCC', 'GPOR', 'GRNT', 'DMLP', 'VTLE', 'TELL', 'COP']
# Peers for INVH: ['AVB', 'EQR', 'MAA', 'SUI', 'ESS', 'UDR', 'ELS', 'CPT', 'AMH']
# Peers for IRTC: ['NVST', 'GMED', 'QDEL', 'IART', 'OCDX', 'NARI', 'ENOV', 'CNMD', 'AXNX', 'ABT']
# Peers for FWBI: ['KRBP', 'DRMA', 'ENSC', 'USRM', 'OPGN']
# Peers for CLPR: ['NXRT', 'CSR', 'BRT', 'AVB']
# Peers for APVO: ['RUBY', 'IMNN', 'CYTH', 'CDIO', 'BRTX', 'NAVB', 'PKBO']
# Peers for FBK: ['TRMK', 'LKFN', 'NWBI', 'NBTB', 'SYBT', 'GWB', 'TCBK', 'HOPE', 'PNC']
# Peers for SELF: ['UNIT', 'LAND', 'FPI', 'CTT', 'CORR', 'PW', 'AMT']
# Peers for LW: ['TSN', 'MKC', 'CAG', 'CPB', 'SJM', 'FLO', 'PPC', 'POST', 'LANC', 'MDLZ']
# Peers for DXC: ['IBM', 'CTSH', 'IT', 'EPAM', 'DOX', 'KD', 'TWKS', 'PRFT', 'GDYN']
# Peers for MSB: ['TMST', 'SXC', 'HAYN', 'ZEUS', 'METC', 'ACNT', 'FRD', 'USAP', 'NUE']
# Peers for KNW: ['CODX', 'BSGM', 'AWH', 'PDEX', 'VANI', 'NVNO', 'AXDX', 'LUCD', 'ABT']
# Peers for XELB: ['CTRN', 'CATO', 'EXPR', 'BEBE', 'TLF', 'CBKCQ', 'CACH', 'DESTQ', 'TJX']
# Peers for PETV: ['ICU', 'BMRA', 'DXR', 'IRIX', 'LNSR', 'TLIS', 'NMTC', 'BEAT', 'ABT']
# Peers for INUV: ['IDN', 'SRAX', 'KLR', 'SDIG', 'CTXS']
# Peers for DHCC: ['PCLB']
# Peers for ULH: ['WERN', 'ARCB', 'RXO', 'MRTN', 'HTLD', 'PTSI', 'DSKE', 'CVLG', 'TSP', 'UBER']
# Peers for MARK: ['VERB', 'QUMU', 'FOXO', 'DATS', 'CTXS']
# Peers for ABEO: ['VTGN', 'TNXP', 'APTX', 'COYA', 'BCDA', 'TARA', 'ACXP', 'ORGS', 'TCON']
# Peers for BIMI: ['AHG']
# Peers for PULM: ['COCP', 'LABP', 'ADIL', 'TTNP', 'GRAY', 'CNTX', 'JNJ']
# Peers for WORX: ['ISPC', 'HCTI', 'ACON', 'CERN']
# Peers for GDS: ['MQ', 'CFLT', 'TSEM', 'CYBR', 'SLAB', 'SYNA', 'GTLB', 'DSGX', 'BMBL']
# Peers for IMXI: ['RPAY', 'PAYA', 'PAY', 'MGI', 'CNDT', 'IIIV', 'CASS', 'IBEX', 'V']
# Peers for COE: ['GNS']
# Peers for YRD: ['QD', 'JFIN', 'XYF']
# No peers found for symbol ZTO
# Peers for JILL: ['GCO', 'PLCE', 'ZUMZ', 'DXLG', 'CURV', 'TLYS', 'CTRN', 'CATO', 'EXPR', 'TJX']
# Peers for CTXR: ['OPTN', 'THRD', 'XERS', 'IMRA', 'CRMD', 'TRVI', 'JNJ']
# Peers for ARCH: ['BTU', 'EVA', 'ARLP', 'CEIX', 'UEC', 'UUUU', 'LEU', 'NRP']
# Peers for VERB: ['SEAC', 'BTCS', 'MRIN', 'GVP', 'QUMU', 'FOXO', 'MARK', 'CTXS']
# Peers for SIMO: ['VSAT', 'FORM', 'TTEC', 'DUOL', 'ALRM', 'JAMF', 'NCNO', 'AUR', 'ACIW', 'BLKB']
# Peers for KT: ['TIMB', 'PSO', 'TME', 'EDR', 'CABO', 'AMC', 'PHI', 'NYT', 'TV']
# Peers for PK: ['HST', 'RHP', 'APLE', 'SHO', 'PEB', 'DRH', 'RLJ', 'SVC', 'XHR']
# Peers for HGV: ['H', 'NCLH', 'WH', 'CHH', 'VAC', 'GBTG', 'TNL', 'TH', 'MCG', 'BKNG']
# Peers for ADEA: ['FROG', 'NABL', 'SWI', 'ZUO', 'ATEN', 'SCWX', 'OSPN', 'XPER', 'TUFN', 'MSFT']
# Peers for DBRG: ['KW', 'SRG', 'WE', 'FRPH', 'ARL', 'TCI', 'NEN']
# Peers for COOP: ['MTG', 'ACT', 'TFSL', 'RDN', 'PFSI', 'WD', 'NMIH', 'AGM', 'MBIN', 'RKT']
# Peers for FTI: ['DEN', 'PBF', 'WHD', 'VET', 'BTU', 'SUN', 'CRC', 'KOS', 'ETRN', 'ERF']
# Peers for GEG: ['PDCO', 'OMI', 'PETQ', 'COSM', 'MCK']
# Peers for MERC: ['RFP']
# Peers for LPTX: ['GLTO', 'CADL', 'TCRX', 'LTRN', 'PMCB', 'UBX', 'RCOR', 'MBIO', 'KA']
# Peers for CKPT: ['BYSI', 'TCON', 'AQB', 'PRAX', 'ALZN', 'MBIO', 'ASMB', 'AVRO', 'XGN']
# Peers for JELD: ['DOOR', 'ROCK', 'JBI', 'MBC', 'PGTI', 'APOG', 'AZZ', 'AMWD', 'NX', 'CARR']
# Peers for PUMP: ['USAC', 'OII', 'RES', 'AROC', 'HLX', 'DRQ', 'SLCA', 'WTTR', 'VTOL', 'SLB']
# Peers for VREX: ['MLAB', 'HSKA', 'CSII', 'VRAY', 'OFIX', 'CUTR', 'SIBN', 'AORT', 'ANGO', 'ABT']
# Peers for NODK: ['UVE', 'HCI', 'GBLI', 'TIG', 'ITIC', 'KFS', 'MILE', 'UIHC', 'ROOT', 'PGR']
# Peers for IIPR: ['FR', 'EGP', 'STAG', 'TRNO', 'LXP', 'MNR', 'PLYM', 'INDT', 'PLD']
# Peers for BYSI: ['SLS', 'GRTX', 'SNTI', 'SYRS', 'BDTX', 'CRDF', 'FBIO', 'AZYO']
# Peers for PLYA: ['PTRA', 'MCRI', 'PATK', 'GDEN', 'OSTK', 'XPEL', 'QRTEA', 'MBUU', 'GIII']
# Peers for SNDR: ['KNX', 'CAR', 'SAIA', 'LSTR', 'HTZ', 'R', 'XPO', 'LYFT', 'WERN', 'UBER']
# Peers for METC: ['SCHN', 'TMST', 'SXC', 'HAYN', 'ZEUS', 'MSB', 'ACNT', 'FRD', 'NUE']
# Peers for AYX: ['APPF', 'NEWR', 'BOX', 'YOU', 'PYCR', 'WK', 'PWSC', 'DV', 'CWAN', 'CTXS']
# Peers for LAUR: ['DUOL', 'GHC', 'HMHC', 'STRA', 'CHGG', 'LRN', 'ATGE', 'COUR', 'UDMY', 'BFAM']
# Peers for SPRC: ['GLMD', 'PHGE', 'VBLT', 'TIKRF', 'QNRX', 'ROSGQ']
# Peers for SNES: ['KOAN', 'BXRX', 'JNJ']
# Peers for ICCH: ['KFS', 'MILE', 'UIHC', 'ROOT', 'HRTG', 'NSEC', 'FACO', 'FGF', 'PGR']
# Peers for CYD: ['MTW', 'NAT', 'TG', 'NL', 'TRC', 'CVEO', 'LXFR', 'EBF']
# Peers for SASI: ['BLBX', 'SLNH', 'ELCO', 'MGTI', 'CTXS']
# Peers for AKTS: ['VSH', 'ROG', 'KN', 'LWLG', 'BELFA', 'AIRG', 'CPSH', 'DYSL', 'APH']
# Peers for WTTR: ['AROC', 'HLX', 'PUMP', 'DRQ', 'SLCA', 'VTOL', 'NESR', 'OIS', 'SLB']
# Peers for ALPP: ['CTS', 'TTMI', 'BHE', 'KE', 'NLST', 'KTCC', 'RFIL', 'DAIO', 'NSYS', 'JBL']
# Peers for FBRX: ['RGLS', 'SQZ', 'BIOR', 'NLTX', 'INFI', 'ATNX', 'GTBP', 'GLS']
# Peers for NISN: ['JG', 'CMCM', 'WETG', 'RENN', 'IFBD', 'MFH', 'CTKYY']
# Peers for SACH: ['NREF', 'REFI', 'AJX', 'AOMR', 'CHMI', 'MITT', 'LFT', 'EARN', 'NLY']
# Peers for FND: ['HD', 'LOW', 'GRWG', 'TTSH', 'LL']
# Peers for EEX: ['PUBM', 'ADV', 'CCO', 'BOC', 'QUOT', 'CTV', 'CDLX', 'ADTH', 'FLNT', 'TTD']
# Peers for AEHL: ['TGSI', 'ILAG']
# Peers for ASH: ['IFF', 'CE', 'RPM', 'EMN', 'AXTA', 'ESI', 'BCPC', 'LTHM', 'AVNT', 'SHW']
# Peers for YEXT: ['RIOT', 'LPSN', 'AVPT', 'MTTR', 'CCSI', 'MARA', 'EXFY', 'BASE', 'CTXS']
# Peers for GOOS: ['LULU']
# Peers for CVNA: ['SAH', 'CWH', 'MNRO', 'EVGO', 'TA', 'ARKO', 'CRMT', 'ONEW', 'ORLY']
# Peers for JCI: ['TT', 'ALLE']
# Peers for OKTA: ['VRSN', 'NET', 'MDB', 'GDDY', 'TWLO', 'AKAM', 'SWCH', 'SQSP', 'DOCN', 'SNOW']
# Peers for DELL: ['AAPL', 'HPQ', 'HPE', 'NTAP', 'WDC', 'PSTG', 'SMCI', 'XRX']
# Peers for SOI: ['NESR', 'OIS', 'TTI', 'BOOM', 'NR', 'FTSI', 'NINE', 'FET', 'SLB']
# Peers for OVID: ['IVVD', 'PBYI', 'TNYA', 'PRAX', 'ORIC', 'GTHX', 'YMAB', 'OLMA', 'GOSS']
# Peers for KREF: ['RC', 'PMT', 'FBRT', 'MFA', 'ARR', 'NYMT', 'BRSP', 'EFC', 'RWT', 'NLY']
# Peers for CARS: ['SSTK', 'GETY', 'YELP', 'CARG', 'ZIP', 'ANGI', 'GRND', 'MAX', 'GOOGL']
# Peers for NDRA: ['BJDX', 'MYO', 'CFMS', 'HSCS', 'AEMD', 'BIOL', 'UTRS', 'AVGR', 'ABT']
# Peers for FPH: ['JOE', 'RMR', 'TRC', 'CHCI']
# Peers for VERI: ['WEAV', 'NN', 'PRCH', 'CCRD', 'KLTR', 'APLD', 'EGAN', 'DSP', 'CTXS']
# Peers for HLNE: ['AMG', 'FSK', 'ORCC', 'AB', 'FOCS', 'BXSL', 'CNS', 'FHI', 'BX']
# Peers for YTRA: ['HOUR', 'VIOT', 'CPHC', 'FLXS', 'LIVE', 'CAAS', 'GP', 'KIRK']
# Peers for CZFS: ['AMNB', 'WTBA', 'CZNC', 'FMAO', 'SHBI', 'CIVB', 'SMMF', 'SFST', 'FNLC', 'PNC']
# Peers for ECIA: ['RMED', 'LHDX', 'INBS', 'MOTS', 'NUWE', 'ABT']
# Peers for ELTP: ['CGTX', 'AQST', 'ADMP', 'LPCN', 'DERM', 'NOVN', 'STSA', 'JNJ']
# Peers for ORMP: ['RVPH', 'ETON', 'DARE', 'LBPH', 'CLSD', 'MYMD', 'ANEB', 'JNJ']
# No peers found for symbol BGI
# Peers for NTZ: ['BNED', 'SUP', 'APRN', 'VNCE', 'KFS', 'LITB', 'CPS', 'HBB']
# Peers for BTU: ['EVA', 'ARCH', 'ARLP', 'CEIX', 'UEC', 'UUUU', 'LEU', 'NRP']
# Peers for BMRA: ['PAVM', 'POCI', 'ICU', 'DXR', 'IRIX', 'LNSR', 'PETV', 'ABT']
# Peers for AEMD: ['FEMY', 'BJDX', 'MYO', 'CFMS', 'HSCS', 'NDRA', 'BIOL', 'UTRS', 'ABT']
# Peers for BOC: ['TTGT', 'THRY', 'PUBM', 'ADV', 'CCO', 'QUOT', 'EEX', 'CTV', 'CDLX', 'TTD']
# Peers for EVTV: ['FFIE', 'WKHS', 'GOEV', 'RIDE', 'CENN', 'AYRO', 'PEV', 'ELMSQ', 'TSLA']
# Peers for AQN: ['PNW', 'UGI', 'NRG', 'VST', 'OGE', 'KEP', 'WTRG']
# Peers for SBFG: ['LARK', 'CBFV', 'LNKB', 'FINW', 'PBHC', 'PNC']
# Peers for COHN: ['FRGE']
# Peers for RCON: ['VIVK', 'MARPS', 'DWSN', 'KNTK', 'ZEST', 'IMPP', 'KLXE', 'PFIE', 'GEOS']
# Peers for SQM: ['PPG', 'ALB', 'FNV', 'MT', 'CRH', 'AEM', 'IFF', 'DD', 'NUE', 'MOS']
# Peers for ATXI: ['ARTL', 'TMBR', 'VLON', 'ELOX', 'JNJ']
# Peers for EMMA: ['NMTR', 'BFRI', 'ANGN', 'KALA', 'CLVR', 'JNJ']
# Peers for CENN: ['FFIE', 'GOEV', 'WKHS', 'MULN', 'RIDE', 'EVTV', 'AYRO', 'PEV', 'TSLA']
# Peers for KTRA: ['CELZ', 'BIOC', 'PTIX', 'XBIO', 'TRVN', 'BLCM']
# Peers for MOXC: ['ICLK']
# Peers for MTNB: ['CADL', 'ISR', 'VXRT', 'ETTX', 'SERA', 'PIRS', 'GALT', 'DBTX']
# Peers for HCM: ['CCXI', 'PCVX', 'SUPN', 'DVAX', 'AMEH', 'SWTX', 'BCRX', 'AUPH']
# Peers for MRUS: ['NAMS', 'QURE', 'PRQR', 'LVTX']
# Peers for CAPR: ['VBIV', 'DMTK', 'CDTX', 'CVM', 'INZY', 'XFOR', 'ARAV', 'MNOV']
# Peers for KPRX: ['VYNE', 'EVOK', 'AGRX', 'AYTU', 'JAGX', 'PALI', 'JNJ']
# Peers for GNTY: ['FLIC', 'CSTR', 'FISI', 'RBB', 'JMSB', 'MCBC', 'ESQ', 'PNC']
# Peers for TPHS: ['SFR', 'CPTP', 'LUXH', 'RFL', 'ALBT', 'CKX', 'DBRG']
# Peers for SPI: ['PXLW', 'EMAN', 'QUIK', 'GSIT', 'ASTI', 'PRSO', 'NVDA']
# Peers for CLLS: ['DBVT', 'APEN', 'LGVN', 'BMEA', 'OPTN', 'CMRX', 'INZY', 'HBIO', 'OMER', 'HITI']
# Peers for IMRN: ['NVCN', 'RNXT', 'LMNL', 'DFFN', 'NERV', 'GMVD', 'BBLG', 'SONN', 'PULM']
# Peers for MVIS: ['VPG', 'SMRT', 'LASR', 'FARO', 'OUST', 'EVLV', 'AEVA', 'ARLO', 'MASS', 'KEYS']
