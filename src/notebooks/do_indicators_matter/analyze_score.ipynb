# %%
import pandas as pd

score_path = '/Users/markwindsor/Desktop/atlas_trade/src/data/score.csv'

score_df = pd.read_csv(score_path)

industry = 'Computers'

computers = score_df[score_df['industry'] == industry].sort_values(by="score", ascending=False).head(50)

computers
# Out:
#      ticker   industry      score
# 3073   IMMR  Computers  31.599120
# 4792   CLSK  Computers  17.421388
# 654    OMQS  Computers  10.143635
# 2224   INTZ  Computers   9.500967
# 4692   BRQS  Computers   8.601150
# 2575   ASUR  Computers   8.468131
# 382     IOT  Computers   7.080990
# 2808   SCKT  Computers   6.208534
# 72     ARBB  Computers   5.754639
# 1466   KBNT  Computers   5.721230
# 1041   RGTI  Computers   4.969373
# 1451   MKFG  Computers   4.941658
# 2878   STRM  Computers   4.774223
# 1108    ECX  Computers   4.609026
# 573    HCTI  Computers   4.469091
# 1109   SMRT  Computers   4.331052
# 596    TDCX  Computers   4.048131
# 934     TSP  Computers   3.669961
# 2250    LNW  Computers   3.441368
# 1478   EVLV  Computers   3.127679
# 4882   DELL  Computers   2.462032
# 4091   ALLT  Computers   2.290430
# 3209   RBBN  Computers   2.096710
# 2135   QMCO  Computers   2.047244
# 591    HUBC  Computers   1.870566
# 2100   CSPI  Computers   1.633160
# ...
