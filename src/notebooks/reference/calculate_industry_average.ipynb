# %%
from ib_insync import *
import pandas as pd
import time
import nasdaqdatalink
import sys

sys.path.append('/Users/markwindsor/Desktop/atlas_trade')
nasdaqdatalink.ApiConfig.api_key = 'zxLNKQydu_qNXQ2tZ7vz'

# %%
AAPL = nasdaqdatalink.get_table('SHARADAR/TICKERS', ticker="AAPL")
df = pd.DataFrame(AAPL)
df
# Out:
#      table  permaticker ticker       name exchange isdelisted  \
# None
# 0      SF1       199059   AAPL  APPLE INC   NASDAQ          N
# 1      SEP       199059   AAPL  APPLE INC   NASDAQ          N
#
#                    category     cusips  siccode      sicsector  ... currency  \
# None                                                            ...
# 0     Domestic Common Stock  037833100     3571  Manufacturing  ...      USD
# 1     Domestic Common Stock  037833100     3571  Manufacturing  ...      USD
#
#                location lastupdated firstadded firstpricedate lastpricedate  \
# None
# 0     California; U.S.A  2023-08-14 2014-09-24     1986-01-01    2023-08-25
# 1     California; U.S.A  2023-08-25 2014-09-24     1986-01-01    2023-08-25
#
#      firstquarter lastquarter  \
# None
# 0      1992-12-31  2023-06-30
# 1      1992-12-31  2023-06-30
#
#                                              secfilings           companysite
# None
# 0     https://www.sec.gov/cgi-bin/browse-edgar?actio...  http://www.apple.com
# 1     https://www.sec.gov/cgi-bin/browse-edgar?actio...  http://www.apple.com
#
# [2 rows x 28 columns]
