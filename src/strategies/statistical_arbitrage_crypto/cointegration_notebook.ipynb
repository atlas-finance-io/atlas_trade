# %%
from cointegration_test import CointegrationTest
import ccxt

exchange = ccxt.binance()
symbol_one = "ADAUSDT"
symbol_two = "MANAUSDT"

# %%
coint = CointegrationTest(exchange, symbol_one, symbol_two)
coint.fetch_single_pair_prices()
coint.visualize_prices()

coint.generate_zscore()
coint.plot_zscore()
coint.plot_spread()
coint.single_pair_cointegeration_check()
coint.stationary_check()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/markwindsor/Desktop/atlas_trade/src/strategies/statistical_arbitrage_crypto/cointegration_notebook.ipynb Cell 2 line 8
#       <a href='vscode-notebook-cell:/Users/markwindsor/Desktop/atlas_trade/src/strategies/statistical_arbitrage_crypto/cointegration_notebook.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> coint.plot_zscore()
#       <a href='vscode-notebook-cell:/Users/markwindsor/Desktop/atlas_trade/src/strategies/statistical_arbitrage_crypto/cointegration_notebook.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> coint.plot_spread()
# ----> <a href='vscode-notebook-cell:/Users/markwindsor/Desktop/atlas_trade/src/strategies/statistical_arbitrage_crypto/cointegration_notebook.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> coint.single_pair_cointegeration_check()
# ...
