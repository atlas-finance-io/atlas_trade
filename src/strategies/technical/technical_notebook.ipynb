# %%
from technical_backtester import TechnicalBacktester
import ccxt

exchange = ccxt.binance()
symbol = "AXSUSDT"
trading_costs = -0.00050

# %%
crossover = TechnicalBacktester(exchange, symbol, 120, trading_costs)
crossover.fetch_prices()
crossover.visualize_prices()
crossover.test_macd_cross()
crossover.print_performance()
# Out:
# ...
# Technical Strategies | INSTRUMENT = AXSUSDT
# ----------------------------------------------------------------------------------------------------
# PERFORMANCE MEASURES:
#
#
# Multiple (Strategy):         0.71013
# Multiple (Buy-and-Hold):     1.187175
# --------------------------------------
# Out-/Underperformance:       -0.477045
#
#
# CAGR:                        -0.65029
# Annualized Mean:             -1.051016
# Annualized Std:              0.608583
# Sharpe Ratio:                -1.068532
# ...
